# %%
import boto3
import pandas as pd
from bertopic import BERTopic

parent_folder = '/Users/username/Desktop/ML/Recommendations/arcane/'
from hydra import compose, initialize
import os

import xml.etree.ElementTree as ET

tree = ET.parse('../../conf/application.run.xml')
root = tree.getroot()

envs_element = root.find('./configuration/envs')
for variable in envs_element.findall('env'):
    name = variable.get('name')
    value = variable.get('value')
    os.environ[name] = value

import sys
sys.path.append('/Users/username/Desktop/ML/Recommendations/arcane/')

from src._utils import load_bertopic_model_from_hf

import json
from io import StringIO
import pickle
from smart_open import open
from bertopic.backend._sentencetransformers import SentenceTransformerBackend

# %%
import requests

# %%
r = requests.post('http://Arcane-env.eba-mrsaixmg.ap-south-1.elasticbeanstalk.com/generate_new_clusters_to_s3')

# %%
r.text
# Out:
# '<html>\r\n<head><title>504 Gateway Time-out</title></head>\r\n<body>\r\n<center><h1>504 Gateway Time-out</h1></center>\r\n<hr><center>nginx</center>\r\n</body>\r\n</html>\r\n'

# %%
from src.articles.ArticleService import ArticleService

# %%
s3_bucket = 'insight-ml-models'
s3_bertopic_folder = 'bertopic'

# %%
run_id = 'YellowLicoriceXray'

# %%
def load_bertopic_model_from_s3(run_id: str, hf_embedding_model_name: str) -> BERTopic:
    filename = 'BERTopic_' + run_id
    foldername = run_id
    s3_path = f's3://{s3_bucket}/{s3_bertopic_folder}/{foldername}/{filename}'

    # Stream the model directly from S3
    with open(s3_path, 'rb',
              transport_params={'client': boto3.client('s3',
                                                       aws_access_key_id=os.environ['AWS_ACCESS_KEY'],
                                                       aws_secret_access_key=os.environ['AWS_SECRET_KEY'])}) as f:
        model = pickle.load(f)
    print('bertopic streamed successfully')

    assert isinstance(model, BERTopic), f"Failed to load model from S3. Model {filename} is not of type BERTopic."
    model.embedding_model = SentenceTransformerBackend(embedding_model=hf_embedding_model_name)
    return model

# %%
def load_json_from_s3(run_id: str, json_file_name: str) -> BERTopic:
    foldername = run_id
    s3_resource = boto3.resource('s3', aws_access_key_id=os.environ['AWS_ACCESS_KEY'], aws_secret_access_key=os.environ['AWS_SECRET_KEY'])
    response = s3_resource.Object(s3_bucket, f'{s3_bertopic_folder}/{foldername}/{json_file_name}.json').get()
    return json.loads(response['Body'].read().decode('utf-8'))
    # return json.dumps(response)

# %%
def load_csv_from_s3(run_id: str, csv_file_name: str) -> BERTopic:
    foldername = run_id
    s3_resource = boto3.resource('s3', aws_access_key_id=os.environ['AWS_ACCESS_KEY'], aws_secret_access_key=os.environ['AWS_SECRET_KEY'])
    response = s3_resource.Object(s3_bucket, f'{s3_bertopic_folder}/{foldername}/{csv_file_name}.csv').get()
    csv_string = response['Body'].read().decode('utf-8')
    return pd.read_csv(StringIO(csv_string))
    # return json.dumps(response)

# %%
article_story_cluster_mapping = load_json_from_s3(run_id = run_id, json_file_name='article_story_cluster_mapping')
story_cluster_mapping = load_json_from_s3(run_id = run_id, json_file_name='story_cluster_mapping')
story_embeddings = load_json_from_s3(run_id = run_id, json_file_name='story_embeddings')
df = load_csv_from_s3(run_id=run_id, csv_file_name='cluster_hierarchy')

# %%
clusters = list(set(story_cluster_mapping.values()))

# %%
outliers = {}
for article_id in article_story_cluster_mapping:
    if article_story_cluster_mapping[article_id]['storyline_id'] == -1:
        outliers.setdefault(article_story_cluster_mapping[article_id]['cluster_id'], []).append(article_id)

# %%
cluster_count = {}
for cluster in outliers:
    cluster_count[cluster] = len(outliers[cluster])

# %%
outliers_count_df = pd.DataFrame([(key, value) for key, value in cluster_count.items()], columns = ['cluster_id', 'outlier_count'])

# %%
df['parent_id'] = df['parent_id'].astype('int')

# %%
df = pd.merge(df, outliers_count_df, how = 'left', left_on = 'parent_id', right_on = 'cluster_id')

# %%
df['total_count'] = df['num_docs'] + df['outlier_count']
df['outlier_percent'] = df['outlier_count']/df['total_count']

# %%
df[df.cluster_id.notnull()].sort_values('total_count', ascending = False)
# Out:
#      Unnamed: 0  parent_id                                        parent_name  \
# 28           28        254             target rs_target_pharma_results_profit
# 26           26        256  mind_mind markets_innerworth mind_innerworth_c...
# 9             9        273                     insurance_rbi_tax_rates_credit
# 142         142          0                0_2023 net_net sales_sales rs_sales
# 29           29        253                      ipo_sebi_gmp_status_allotment
# 15           15        267                     oil_china_oil prices_pm_prices
# 4             4        278          mutual_funds_fund_definition_mutual funds
# 39           39        243                      air_air india_musk_tesla_byju
# 11           11        271                         dollar_gold_fed_rupee_rate
# 24           24        258            adani_bank_hdfc_stocks watch_mint adani
# 18           18        264       nifty_sensex_stock market_things_things know
# 61           61        221                    ai_openai_amazon_google_chatgpt
# 62           62        220               suzuki_maruti_maruti suzuki_hero_suv
# 45           45        237  buy sell_stocks buy_sell_recommends_recommends...
# 131         131        151                steel_tata steel_jsw steel_jsw_tata
# 138         138        144    agri picks_picks report_agri_geojit_2023 geojit
#
#                                   child_storyline_list  child_left_id  \
# 28   [8, 9, 12, 26, 29, 38, 48, 55, 57, 63, 65, 86,...          160.0
# 26   [5, 24, 31, 39, 49, 52, 56, 61, 72, 76, 78, 89...          249.0
# 9    [6, 18, 19, 25, 34, 37, 41, 47, 59, 62, 66, 82...          260.0
# 142                                                 []            NaN
# 29   [1, 11, 15, 22, 44, 51, 69, 74, 77, 79, 110, 1...          252.0
# 15                   [7, 16, 33, 35, 36, 87, 109, 117]          262.0
# 4              [13, 30, 43, 50, 53, 98, 129, 132, 137]          195.0
# 39               [3, 14, 32, 45, 68, 70, 71, 103, 114]          238.0
# 11    [10, 27, 58, 64, 81, 88, 95, 120, 121, 128, 139]          250.0
# 24             [17, 21, 42, 73, 75, 80, 101, 135, 141]          247.0
# 18                         [20, 23, 85, 130, 133, 136]          227.0
# 61                             [28, 83, 102, 116, 124]          193.0
# 62                                        [40, 54, 90]           54.0
# 45                                  [67, 99, 115, 127]          170.0
# 131                                           [60, 96]           96.0
# 138                                          [94, 123]           94.0
#
#                                        child_left_name  child_right_id  \
# 28   finance_bajaj finance_bajaj_finance share_hous...           251.0
# 26   innerworth_innerworth mind_mind markets_mind_c...           214.0
# 9                       rbi_rates_credit_loan_mortgage           268.0
# 142                                                NaN             NaN
# 29                       ipo_gmp_status_allotment_coal           182.0
# 15                    oil_china_oil prices_prices_opec           191.0
# 4           mutual_funds_fund_mutual funds_mutual fund           184.0
# 39                    air_air india_byju_indigo_flight           172.0
# 11                    dollar_rupee_fed_inflation_paise           171.0
# 24       adani_stocks watch_jio_mint adani_adani ports           187.0
# 18      nifty_sensex_nifty 50_sensex nifty_trade setup           146.0
# 61                  ai_openai_chatgpt_nvidia_microsoft           175.0
# 62        hero_motocorp_hero motocorp_bajaj auto_bajaj           153.0
# 45   buy sell_stocks buy_sell_vaishali parekh_vaishali           190.0
# 131                jsw steel_jsw_steel_jindal_mint jsw            60.0
# 138     wheat_2023 geojit_picks report_agri picks_agri           123.0
#
#                                       child_right_name  distance  level  \
# 28            target rs_target_pharma_results_dividend  1.089306    6.0
# 26                    job_retirement_money_work_people  1.100493   10.0
# 9                  insurance_tax_gst_income tax_income  1.282598    5.0
# 142                                                NaN       NaN    4.0
# 29   sebi_zee_mint sebi_entertainment_zee entertain...  1.081899   12.0
# 15                          pm_modi_g20_pm modi_summit  1.214840    8.0
# 4          definition_example_examples_formula_trading  1.414653    3.0
# 39                          tesla_ev_electric_ford_ola  1.031884   12.0
# 11            gold_silver_mint gold_gold silver_prices  1.267402    2.0
# 24               bank_hdfc_hdfc bank_bank target_kotak  1.112572    6.0
# 18          things know_market opens_things_know_opens  1.191756    4.0
# 61                  amazon_meta_facebook_google_tiktok  0.963939    7.0
# 62             suzuki_maruti_maruti suzuki_suv_hyundai  0.962759    9.0
# 45   trade spotlight_spotlight_hot stocks_hot_stock...  1.010684    4.0
# 131            steel_tata steel_tata_nmdc_steel closed  0.644728    5.0
# 138    picks report_agri picks_agri_geojit_2023 geojit  0.552096    6.0
#
#      num_docs                                           doc_list  cluster_id  \
# 28     9259.0  [308, 1108, 2227, 2881, 3390, 3692, 5023, 5492...       254.0
# 26     7517.0  [83, 444, 546, 609, 3018, 3499, 3709, 3884, 41...       256.0
# 9      8049.0  [67, 127, 521, 1179, 1568, 1870, 2438, 4065, 4...       273.0
# 142   11562.0  [12, 25, 41, 42, 48, 101, 103, 123, 136, 146, ...         0.0
# 29     8766.0  [445, 856, 973, 1350, 1474, 1976, 2079, 2148, ...       253.0
# 15     4670.0  [56, 238, 286, 294, 364, 794, 841, 1260, 1444,...       267.0
# 4      3716.0  [68, 326, 1128, 1212, 3348, 3726, 4136, 4412, ...       278.0
# 39     5420.0  [30, 248, 537, 2221, 3618, 3840, 3886, 5057, 5...       243.0
# 11     4044.0  [20, 398, 612, 669, 840, 872, 1002, 1187, 1299...       271.0
# 24     3694.0  [164, 440, 482, 616, 721, 747, 1132, 1468, 150...       258.0
# 18     2382.0  [469, 1223, 1288, 1372, 2265, 2435, 3156, 3475...       264.0
# 61     1560.0  [698, 1141, 1596, 2220, 2846, 3125, 4778, 4820...       221.0
# 62     1191.0  [125, 250, 1856, 2266, 2307, 2563, 2793, 3291,...       220.0
# 45      908.0  [381, 1705, 1724, 1891, 2024, 2216, 2251, 2384...       237.0
# 131     603.0  [227, 503, 732, 762, 2050, 2084, 2366, 2929, 3...       151.0
# 138     407.0  [1129, 1522, 2906, 3071, 3205, 3358, 3486, 409...       144.0
#
#      outlier_count  total_count  outlier_percent
# 28         15199.0      24458.0         0.621433
# 26          7897.0      15414.0         0.512326
# 9           3921.0      11970.0         0.327569
# 142            2.0      11564.0         0.000173
# 29          1825.0      10591.0         0.172316
# 15          2496.0       7166.0         0.348311
# 4           3403.0       7119.0         0.478017
# 39           673.0       6093.0         0.110455
# 11           451.0       4495.0         0.100334
# 24           287.0       3981.0         0.072092
# 18           788.0       3170.0         0.248580
# 61           864.0       2424.0         0.356436
# 62           415.0       1606.0         0.258406
# 45            55.0        963.0         0.057113
# 131            7.0        610.0         0.011475
# 138           92.0        499.0         0.184369

# %% [markdown]
# ### Identifying stories which should not be part of the clusters

# %%
df[df.parent_id.isin([17, 41, 51, 179, 310, 345, 361])]
# Out:
#      Unnamed: 0  parent_id                                   parent_name  \
# 405         405         17            17_daily voice_voice_daily_manager
# 429         429         41              41_jpmorgan_republic_goldman_svb
# 439         439         51           51_cnbc daily_daily open_daily_cnbc
# 567         567        179  179_technical view_view_view nifty_technical
# 698         698        310   310_manual_manual nifty_nifty_strike manual
# 733         733        345     345_inclusion_jpmorgan_indian bonds_index
# 749         749        361                 361_day mood_mid day_mood_mid
#
#     child_storyline_list  child_left_id child_left_name  child_right_id  \
# 405                   []            NaN             NaN             NaN
# 429                   []            NaN             NaN             NaN
# 439                   []            NaN             NaN             NaN
# 567                   []            NaN             NaN             NaN
# 698                   []            NaN             NaN             NaN
# 733                   []            NaN             NaN             NaN
# 749                   []            NaN             NaN             NaN
#
#     child_right_name  distance  level  num_docs  \
# 405              NaN       NaN   18.0     539.0
# 429              NaN       NaN   18.0     317.0
# 439              NaN       NaN   18.0     289.0
# 567              NaN       NaN   18.0     128.0
# 698              NaN       NaN   18.0      69.0
# 733              NaN       NaN   18.0      59.0
# 749              NaN       NaN   17.0      54.0
#
#                                               doc_list  cluster_id  \
# 405  [756, 1121, 1350, 1365, 1407, 1502, 1858, 1948...         NaN
# 429  [113, 306, 1865, 2060, 2445, 2498, 2760, 2910,...         NaN
# 439  [106, 183, 298, 366, 2249, 2943, 3769, 4538, 4...         NaN
# 567  [938, 1027, 2134, 2320, 2483, 3238, 4333, 7776...         NaN
# 698  [2014, 2759, 3055, 13200, 15411, 22807, 22848,...         NaN
# 733  [12695, 13305, 21444, 21625, 22275, 28823, 293...         NaN
# 749  [1006, 2530, 6459, 8335, 30295, 30873, 32484, ...         NaN
#
#      outlier_count  total_count  outlier_percent
# 405            NaN          NaN              NaN
# 429            NaN          NaN              NaN
# 439            NaN          NaN              NaN
# 567            NaN          NaN              NaN
# 698            NaN          NaN              NaN
# 733            NaN          NaN              NaN
# 749            NaN          NaN              NaN

# %%
import numpy as np

# %%
random_businessworld_articles = np.random.choice([x for x in article_story_cluster_mapping if article_story_cluster_mapping[x]['storyline_id'] in [77, 102, 129, 193, 209, 215, 286, 302]], 100)

# %%
bw_articles = {}

# %%
from tqdm.notebook import tqdm

# %%
for art in tqdm(random_businessworld_articles):
    article = ArticleService.get_article_json_from_s3_and_api(art)
    bw_articles[art] = {}
    bw_articles[art]['article'] = article
    bw_articles[art]['title'] = article['title']
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
bw_articles['6555c0bf4b13023f9348cc9c']
# Out:
# {'article': {'meta_data': {'is_premium_article': False,
#    'title': 'Filinvest Land expects higher earnings this year - BusinessWorld Online',
#    'short_description': 'LISTED property developer Filinvest Land, Inc. (FLI) is bullish about its prospects for the rest of the year and expects profit growth for 2023 as the economy improves. “The Philippines is growing, and we are optimistic that we will grow more unless there is anything happening outside of the Philippines. Here within the country, our […]',
#    'published_time': '2023-08-28T16:05:39+00:00',
#    'last_updated_time': '2023-08-28T11:18:48+00:00',
#    'image_url': 'https://www.bworldonline.com/wp-content/uploads/2021/11/Filinvest-Land-logo.jpg',
#    'authors': ['CEDadiantiTyClea'],
#    'tags': [],
#    'read_time': '2 minutes',
#    'is_document': True},
#   'cleaned_text': 'LISTED property developer Filinvest Land, Inc. (FLI) is bullish about its prospects for the rest of the year and expects profit growth for 2023 as the economy improves. “The Philippines is growing, and we are optimistic that we will grow more unless there is anything happening outside of the Philippines. Here within the country, our fundamentals seem to be good,” said FLI Director Michael Edward T. Gotianun on the sidelines of the company’s launch event last week. Asked about the prospects for the rest of the year, he said net income is expected to be better this year compared with a year ago despite economic headwinds. FLI is the property development company of the Gotianun’s Filinvest group of companies. In 2022, FLI recorded a 24% decline in net income to P2.8 billion from P3.8 billion the prior year. Mr. Gotianun said this year’s growth drivers for FLI include the improving economic situation and surging investor interest. “The economy is improving, and there seems to be a lot of interest,” he said. “Everybody is positive about the economy. However, our concern will be the outside, like China, with all their problems going on now. You don’t know if there might be a spillover. We cannot control that. So, we just hope it does not spill over to us.” In the first half, FLI booked a 15% surge in its attributable net income to P1.39 billion. Its total consolidated revenues and other income also rose by 8% to P9.92 billion on the back of growth from its residential and rental business segments. “Business is good. So let’s hope that it stays good,” he added. FLI President and Chief Executive Officer Tristaneil D. Las Marias previously said that the developer continued to achieve growth in its residential and rental business segments during the first six months of the year. “We are pleased that our efforts led to satisfactory results as we continued to sustain our sales and marketing activities,” he said. “We remain focused on meeting our customers’ needs as we target to further grow our business this year, with further residential launches planned in the second half,” he added. As of Aug. 25, FLI shares were at 66 centavos apiece, down one centavo or 1.49% from its previous close of 67 centavos the day prior. — Revin Mikhael D. Ochave',
#   'article_images': ['https://www.bworldonline.com/wp-content/uploads/2021/11/Filinvest-Land-logo.jpg'],
#   'articleId': '6555c0bf4b13023f9348cc9c',
#   'url': 'https://www.bworldonline.com/corporate/2023/08/29/541998/filinvest-land-expects-higher-earnings-this-year/',
#   'title': 'Filinvest Land expects higher earnings this year - BusinessWorld Online',
#   'shortDescription': 'LISTED property developer Filinvest Land, Inc. (FLI) is bullish about its prospects for the rest of the year and expects profit growth for 2023 as the economy improves. “The Philippines is growing, and we are optimistic that we will grow more unless there is anything happening outside of the Philippines. Here within the country, our […]',
#   'publishedTime': '2023-08-28T16:05:39+00:00',
#   'lastUpdatedTime': '2023-08-28T11:18:48+00:00',
#   'tags': None,
#   'articleImageUrl': 'https://www.bworldonline.com/wp-content/uploads/2021/11/Filinvest-Land-logo.jpg',
#   'category': None,
#   'authors': ['CEDadiantiTyClea'],
#   'isPremiumArticle': False,
#   'source': {'sourceId': '65559d0c96fb32eef21a562f',
#    'sourceName': 'business-world',
#    'sourceLogo': 'https://pbs.twimg.com/profile_images/731046562848071680/1bYZ7dkg_400x400.jpg'},
#   'sourceId': '65559d0c96fb32eef21a562f',
#   'sourceName': 'business-world',
#   'sourceLogo': 'https://pbs.twimg.com/profile_images/731046562848071680/1bYZ7dkg_400x400.jpg'},
#  'title': 'Filinvest Land expects higher earnings this year - BusinessWorld Online'}

# %%
[(i, x['title']) for i, x in bw_articles.items()]
# Out:
# [('657135c953e8a6117bd31f06',
#   'DoE calls for accelerated retirement, repurposing of coal-fired power plants - BusinessWorld Online'),
#  ('6555bea84b13023f9348c4ba',
#   'T-bill, bond yields likely to inch higher - BusinessWorld Online'),
#  ('6555c1f24b13023f9348d0f0',
#   'Peso may move sideways vs dollar ahead of inflation data - BusinessWorld Online'),
#  ('6555c12d4b13023f9348ce74',
#   'Yields on gov’t debt rise - BusinessWorld Online'),
#  ('6555cc344b13023f934a63d5',
#   'Rice prices soar, fanning fears of food inflation spike in Asia'),
#  ('6555c0b84b13023f9348cc82',
#   'Peso strengthens on dovish Fed minutes - BusinessWorld Online'),
#  ('6555bec24b13023f9348c530',
#   'DoE says still on track to hit renewables goal - BusinessWorld Online'),
#  ('6555c8584b13023f93492638',
#   'Maynilad’s modular plant starts treating water - BusinessWorld Online'),
#  ('6555c47d4b13023f9348d8ba',
#   'Maynilad sets aside P1.14B to upgrade water treatment plants - BusinessWorld Online'),
#  ('6555c4e94b13023f9348da91',
#   'Tripping incidents declined in 3 main grids, says NGCP - BusinessWorld Online'),
#  ('6555c2844b13023f9348d25d',
#   'PSA to start farmer, fisherfolk census in Sept. - BusinessWorld Online'),
#  ('651de104a662d76276b7fddc',
#   'India decides to allow export of rice to Singapore in view of special relationship'),
#  ('656558721fc4586a032ad7fe',
#   'Shares may go down on profit taking, rate bets - BusinessWorld Online'),
#  ('6555c3c34b13023f9348d588',
#   'Prime Energy to supply condensate to Abu Dhabi firm - BusinessWorld Online'),
#  ('6555becd4b13023f9348c55b',
#   'Philippines ranks 68th in remote work locations list - BusinessWorld Online'),
#  ('6555c48b4b13023f9348d8eb',
#   'Rediscount facility left untouched in August - BusinessWorld Online'),
#  ('6555c4fc4b13023f9348dae4',
#   'On the road to recovery (Part 1): Prices, rents recover as M.Manila condominium market rebounds - BusinessWorld Online'),
#  ('6564085d31adde713f95b97f',
#   'MPT South allocates nearly P12B to fund projects’ construction - BusinessWorld Online'),
#  ('6555c3654b13023f9348d43d',
#   'Raslag in talks with Hong Kong firm for potential energy tie-up - BusinessWorld Online'),
#  ('6570411f53e8a6117bd30c03',
#   'Meralco expects lower power generation charge for December - BusinessWorld Online'),
#  ('6555c4fc4b13023f9348dae2',
#   'BSP extends ‘hawkish’ rate pause - BusinessWorld Online'),
#  ('6555c8d44b13023f9349279b',
#   'El Niño also expected to affect PHL rice suppliers Vietnam, Thailand - BusinessWorld Online'),
#  ('6555c15f4b13023f9348cf3f',
#   'Retail dollar bond offer to start on Wednesday - BusinessWorld Online'),
#  ('6555c1a64b13023f9348d03b',
#   'Farm equipment maker bats for RCEF extension, says goals unmet - BusinessWorld Online'),
#  ('6571c35925cc9a343f03fcf7',
#   'Rice stocks on the boil amid fears of worst shortfall in yield in two decades'),
#  ('6555c51d4b13023f9348db7a',
#   'Japanese investors pressing for more ecozone proclamations - BusinessWorld Online'),
#  ('6555c1234b13023f9348ce43',
#   'RE transition to require power grids to make major adjustments — report - BusinessWorld Online'),
#  ('6555c4214b13023f9348d732',
#   'Stocks decline on profit taking, weak China data - BusinessWorld Online'),
#  ('6555c0bf4b13023f9348cc9c',
#   'Filinvest Land expects higher earnings this year - BusinessWorld Online'),
#  ('6555bee74b13023f9348c5be',
#   'Bargain hunting, rate concerns to drive trading - BusinessWorld Online'),
#  ('6555c08c4b13023f9348cbcb',
#   'Dairy regulator issues funding plea for expansion plans - BusinessWorld Online'),
#  ('6555c4c64b13023f9348d9f2',
#   'Rate cuts eyed if inflation falls below 4% - BusinessWorld Online'),
#  ('6555c0254b13023f9348ca09',
#   'Agriculture damage from ‘Goring’ hits P898.4 million - BusinessWorld Online'),
#  ('656e06149994965ac4b4c051',
#   'Megaworld partners with Suntrust to develop new township project in Palawan - BusinessWorld Online'),
#  ('6555c42a4b13023f9348d765',
#   'New SM mall opens in Bataan - BusinessWorld Online'),
#  ('6555c4f34b13023f9348daba',
#   'Marcos calls rice supply adequate in warning to hoarders, smugglers - BusinessWorld Online'),
#  ('656e07a49994965ac4b4c543',
#   'T-bill, bond rates to track secondary mart levels - BusinessWorld Online'),
#  ('6555c1734b13023f9348cf9d',
#   'Yields on gov’t securities decline after inflation data - BusinessWorld Online'),
#  ('6555bfe14b13023f9348c8d2',
#   'Government fully awards Treasury bills - BusinessWorld Online'),
#  ('6555ccd24b13023f934ad9c2',
#   'India rice ban: Some US shops impose buying limit amid price hike and panic buying'),
#  ('6555c23d4b13023f9348d1b4',
#   'How does Philippine sectoral debt as share of GDP stand along with other emerging markets in Asia in Q2? - BusinessWorld Online'),
#  ('6555bf854b13023f9348c76e',
#   'Fitch expects continued pressure on regional currencies until Fed wraps up tightening cycle - BusinessWorld Online'),
#  ('6555bfc44b13023f9348c850',
#   'SEC\xa0readies listing framework for energy firms - BusinessWorld Online'),
#  ('6555c1a54b13023f9348d038',
#   'Electricity rates down in April, Meralco says - BusinessWorld Online'),
#  ('6555c4014b13023f9348d692',
#   'Philippine shares decline on weak US, China data - BusinessWorld Online'),
#  ('6555bf274b13023f9348c668',
#   'DoTr’s proposed 15-year NAIA concession won’t do much, says consortium - BusinessWorld Online'),
#  ('6555cb624b13023f9349d0b2',
#   'Chilean Peso (CLP): Overview, History, Exchange Rate'),
#  ('6555c8494b13023f9349249e',
#   'Australia’s Digital Classifieds Group acquires Lamudi Philippines and Indonesia - BusinessWorld Online'),
#  ('6555c5744b13023f9348dcea',
#   'Further tightening seen with inflation unlikely to ease - BusinessWorld Online'),
#  ('6555c2184b13023f9348d149',
#   'Manila climbs in financial centers list - BusinessWorld Online'),
#  ('6555c0174b13023f9348c9cc',
#   'National Government outstanding debt - BusinessWorld Online'),
#  ('6555c1404b13023f9348cec6',
#   'Megaworld to build 374-room Savoy Hotel in Pampanga township - BusinessWorld Online'),
#  ('6555c4034b13023f9348d6a8',
#   'IMF raises Philippine growth forecast\xa0 - BusinessWorld Online'),
#  ('6555c1a14b13023f9348d02a',
#   '8990 Holdings optimistic of hitting P24-B revenues - BusinessWorld Online'),
#  ('6555c32e4b13023f9348d3b2',
#   'Megawide’s NAIA move hinged on partner, control - BusinessWorld Online'),
#  ('6555c05f4b13023f9348cb10',
#   'Seaweed touted as low-cost animal feed - BusinessWorld Online'),
#  ('6555c1354b13023f9348ce93',
#   'Sia’s listed businesses post robust profit growth - BusinessWorld Online'),
#  ('6555c3a54b13023f9348d51a',
#   'Danish company sees opportunities in solar solutions for PHL agri sector - BusinessWorld Online'),
#  ('6555c14a4b13023f9348cef2',
#   'Term deposit yields mixed on slower inflation - BusinessWorld Online'),
#  ('6555c0584b13023f9348caf4',
#   'NG gross borrowings slump in Sept. - BusinessWorld Online'),
#  ('6555bed24b13023f9348c573',
#   'PHL economy seen to grow by 5.8% this year - BusinessWorld Online'),
#  ('6555c0814b13023f9348cb96',
#   'Growth on track to hit 6-7% — BSP - BusinessWorld Online'),
#  ('651dd6e8a662d76276b7e340',
#   'Rice prices soar to highest levels in almost 15 years in Asia'),
#  ('6555bfdc4b13023f9348c8bb',
#   'Peso likely to strengthen further ahead of June inflation data - BusinessWorld Online'),
#  ('6555c4284b13023f9348d74f',
#   'ADB financial assistance to PHL hits $3B in 2022 - BusinessWorld Online'),
#  ('6555cc194b13023f934a4ff0',
#   'India allows export of over 10 lakh tonnes of non-basmati white rice to seven countries'),
#  ('6555c0804b13023f9348cb8e',
#   'Gov’t partially awards Treasury bills at higher rates - BusinessWorld Online'),
#  ('6555c3e24b13023f9348d608',
#   'Philippines improves in 2023 Fragile States Index - BusinessWorld Online'),
#  ('6555bf2e4b13023f9348c682',
#   'PH1 expects more possibilities after its acquisition by Megawide - BusinessWorld Online'),
#  ('6555c0e54b13023f9348cd3d',
#   'Meralco renewables unit invests nearly P16B for SPNEC control - BusinessWorld Online'),
#  ('6555c4964b13023f9348d919',
#   'Hotel101 expects P7B from Japan location - BusinessWorld Online'),
#  ('6555c10d4b13023f9348cdeb',
#   'DoF eyes temporary zero tariffs on rice - BusinessWorld Online'),
#  ('6555c39c4b13023f9348d4f8',
#   'Peso rebounds on US debt limit deal optimism - BusinessWorld Online'),
#  ('6555c3a44b13023f9348d511',
#   'Meralco looks at nuclear power as long-term solution - BusinessWorld Online'),
#  ('6555bff64b13023f9348c931',
#   'Green energy Round 2 winners given more time to submit post-auction requirements - BusinessWorld Online'),
#  ('6560d6cfe1d8342798a46aab',
#   'Hog, chicken egg output rise in 3rd quarter - BusinessWorld Online'),
#  ('6555bffe4b13023f9348c950',
#   'ACEN readies more investments abroad this year - BusinessWorld Online'),
#  ('6555c1634b13023f9348cf58',
#   'Peso drops further due to month-end dollar demand - BusinessWorld Online'),
#  ('6555c0d14b13023f9348ccf2',
#   'Maynilad expects pause in service interruptions as Ipo water levels rise - BusinessWorld Online'),
#  ('6555c3704b13023f9348d465',
#   'Alternergy takes RE firm - BusinessWorld Online'),
#  ('6555c0904b13023f9348cbdb',
#   'PHL on track to hit medium-term targets — Diokno \xa0 - BusinessWorld Online'),
#  ('6555c4a44b13023f9348d958',
#   'PHL shares climb as Biden signs debt limit deal - BusinessWorld Online'),
#  ('6555c00d4b13023f9348c992',
#   'DoTr still open to solicited proposals for NAIA O&M - BusinessWorld Online'),
#  ('6567fb2f207bb033b910ed5b',
#   'EDC board approves P10-B fixed rate bonds - BusinessWorld Online'),
#  ('6555c05c4b13023f9348cb05',
#   'BDO slips as US credit rating downgrade affects PHL market - BusinessWorld Online'),
#  ('6555bf3e4b13023f9348c6b3',
#   'Meralco gains de-loading capacity\xa0 - BusinessWorld Online'),
#  ('6555c4464b13023f9348d7df',
#   'BSP posts double-digit drop in first-half net income\xa0 - BusinessWorld Online'),
#  ('6555c05a4b13023f9348cafd',
#   'Peso down on strong US data - BusinessWorld Online'),
#  ('6555c3f44b13023f9348d655',
#   'Quality manufacturing jobs seen as key to keeping domestic economy ‘robust’ - BusinessWorld Online'),
#  ('6555c37e4b13023f9348d493',
#   'Iloilo City mayor backs waste-to-energy project - BusinessWorld Online'),
#  ('65716df1441fea11ec37f749',
#   'Anticipating an attractive Philippine stock market - BusinessWorld Online'),
#  ('6555c5534b13023f9348dc5e',
#   'Malampaya SC renewal touted as key DoE achievement - BusinessWorld Online'),
#  ('6560e06fe1d8342798a4790d',
#   'Shares up on positive sentiment, foreign buying - BusinessWorld Online'),
#  ('6555c1774b13023f9348cfb7',
#   'Shares decline further ahead of US inflation data - BusinessWorld Online'),
#  ('6555c4884b13023f9348d8dd',
#   'PHL inflation slows for sixth straight month in July - BusinessWorld Online'),
#  ('6555c4984b13023f9348d926',
#   'Unstable power on Panay could persist indefinitely - BusinessWorld Online')]

# %%
[x for x in article_story_cluster_mapping if article_story_cluster_mapping[x]['storyline_id'] in [77, 102, 129, 193, 209, 215, 286, 302]]
# Out:
# ['6555c35c4b13023f9348d419',
#  '6555c05e4b13023f9348cb0b',
#  '6555beaf4b13023f9348c4e3',
#  '6555c4844b13023f9348d8cc',
#  '6555c2dc4b13023f9348d30e',
#  '6560dd95e1d8342798a474a3',
#  '6555c0e64b13023f9348cd40',
# dict_keys(['meta_data', 'cleaned_text', 'article_images', 'articleId', 'url', 'title', 'shortDescription', 'publishedTime', 'lastUpdatedTime', 'tags', 'articleImageUrl', 'category', 'authors', 'isPremiumArticle', 'source', 'sourceId', 'sourceName', 'sourceLogo'])

# %%
stop_words = ['cnbc', 'businessworld']

# %%
# exclusion_story_ids = [1, 45, 320, 326, 347, 366, 370, 30, 33, 44, 55, 67, 105, 209, 216, 309, 74, 234]

# %%
exclusion_story_ids = [77, 102, 129, 193, 209, 215, 286, 302]

# %%
df[df.parent_id.isin(exclusion_story_ids)]
# Out:
#      Unnamed: 0  parent_id                                        parent_name  \
# 465         465         77  77_businessworld online_businessworld_online_acen
# 490         490        102  102_businessworld online_businessworld_online_...
# 517         517        129  129_bsp_businessworld online_businessworld_online
# 581         581        193                193_rice_export_basmati_non basmati
# 597         597        209  209_businessworld_businessworld online_philipp...
# 603         603        215  215_rice_businessworld online_businessworld_on...
# 674         674        286  286_online psei_online shares_psei_businesswor...
# 690         690        302  302_peso_online peso_vs dollar_dollar business...
#
#     child_storyline_list  child_left_id child_left_name  child_right_id  \
# 465                   []            NaN             NaN             NaN
# 490                   []            NaN             NaN             NaN
# 517                   []            NaN             NaN             NaN
# 581                   []            NaN             NaN             NaN
# 597                   []            NaN             NaN             NaN
# 603                   []            NaN             NaN             NaN
# 674                   []            NaN             NaN             NaN
# 690                   []            NaN             NaN             NaN
#
#     child_right_name  distance  level  num_docs  \
# 465              NaN       NaN    8.0     240.0
# 490              NaN       NaN    8.0     194.0
# 517              NaN       NaN    8.0     162.0
# 581              NaN       NaN    5.0     118.0
# 597              NaN       NaN    8.0     107.0
# 603              NaN       NaN    5.0     101.0
# 674              NaN       NaN    6.0      74.0
# 690              NaN       NaN    5.0      70.0
#
#                                               doc_list  cluster_id  \
# 465  [75, 122, 2595, 3037, 3601, 3771, 4678, 4733, ...         NaN
# 490  [161, 334, 922, 1128, 1138, 1520, 2010, 3108, ...         NaN
# 517  [1325, 2980, 3506, 3767, 3896, 4064, 4862, 490...         NaN
# 581  [3848, 3999, 6239, 6852, 11674, 12595, 12801, ...         NaN
# 597  [1899, 1993, 2837, 4447, 4787, 6321, 6400, 673...         NaN
# 603  [46, 63, 802, 1585, 3838, 6352, 6534, 7159, 79...         NaN
# 674  [18, 4454, 5444, 6277, 8508, 8665, 10033, 1009...         NaN
# 690  [2448, 3262, 4820, 9566, 10111, 10203, 10840, ...         NaN
#
#      outlier_count  total_count  outlier_percent
# 465            NaN          NaN              NaN
# 490            NaN          NaN              NaN
# 517            NaN          NaN              NaN
# 581            NaN          NaN              NaN
# 597            NaN          NaN              NaN
# 603            NaN          NaN              NaN
# 674            NaN          NaN              NaN
# 690            NaN          NaN              NaN

# %%
non_india_fin_stories = [77, 102, 129, 193, 209, 215, 286, 302]

# %%
non_fin_stories = list(set(exclusion_story_ids) - set(non_india_fin_stories))

# %% [markdown]
# #### Marking documents of irrelevant stories

# %%
from sql.PostgresDatabaseOperation import PostgresDatabaseOperation

# %%
non_india_docs = [x for x in article_story_cluster_mapping if article_story_cluster_mapping[x]['storyline_id'] in non_india_fin_stories]

# %%
non_fin_docs = [x for x in article_story_cluster_mapping if article_story_cluster_mapping[x]['storyline_id'] in non_fin_stories]

# %%
len(non_india_docs), len(non_fin_docs)
# Out:
# (1066, 0)

# %% [markdown]
# ##### Non India financial news

# %%
with PostgresDatabaseOperation() as cursor:
    sql = """INSERT INTO manual_article_attributes (article_id, financial_news, relevant_for_india)
            VALUES (%s, %s, %s)
            """
    for doc in non_india_docs:
        cursor.execute(sql, (doc, True, False))

# %% [markdown]
# ##### Non financial India news

# %%
with PostgresDatabaseOperation() as cursor:
    sql = """INSERT INTO manual_article_attributes (article_id, financial_news, relevant_for_india)
            VALUES (%s, %s, %s)
            """
    for doc in non_fin_docs:
        cursor.execute(sql, (doc, False, True))

# %% [markdown]
# ### Saving clustering details to DB

# %%
with initialize(config_path="../../conf"):
    # Compose the configuration
    cfg = compose(config_name="ClustersResetService.yaml")

# %%
bertopic_model = load_bertopic_model_from_s3(run_id=run_id, hf_embedding_model_name='BAAI/bge-large-en-v1.5')
# Out:
# bertopic streamed successfully

# %%
import time

# %%
num_docs = len(bertopic_model.topics_)
random_state = 86
model_name = 'BAAI/bge-large-en-v1.5'
embedding_size = 1024

# %%
from sql.clustering.ClusteringSQL import ClusteringSQL

# %%
def save_clustering_run_details_to_db():
    run_details_dict = dict(cfg)
    run_details_dict['num_docs'] = num_docs
    run_details_dict['random_state'] = random_state
    run_details_dict['run_time'] = time.time()
    run_details_dict['run_id'] = run_id
    run_details_dict['embedding_model_name'] = model_name
    run_details_dict['embedding_size'] = embedding_size

    ClusteringSQL.insert_clustering_run_details(clustering_run_config=run_details_dict,
                                                clustering_run_id=run_id)

# %%
save_clustering_run_details_to_db()

# %%
from copy import deepcopy

# %%
renamed_hierarchy_df = deepcopy(df)
renamed_hierarchy_df = renamed_hierarchy_df.rename(columns={'cluster_id': 'parent_id', 'cluster_name': 'parent_name', 'storylines': 'child_storyline_list',
                                                        'left_child_id': 'child_left_id', 'left_child_name': 'child_left_name',
                                                        'right_child_id': 'child_right_id', 'right_child_name': 'child_right_name'})

# %%
ClusteringSQL.save_article_story_cluster_mapping(article_story_cluster_mapping=article_story_cluster_mapping, clustering_run_id=run_id)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[472], line 1
# ----> 1 ClusteringSQL.save_article_story_cluster_mapping(article_story_cluster_mapping=article_story_cluster_mapping, clustering_run_id=run_id)
#
# File ~/Desktop/ML/Recommendations/arcane/sql/clustering/ClusteringSQL.py:102, in ClusteringSQL.save_article_story_cluster_mapping(article_story_cluster_mapping, clustering_run_id)
#     100 chunk_size = 10000
#     101 for chunk in chunked_data(bulk_data, chunk_size):
# --> 102     cursor.executemany(insert_sql, chunk)
#     104 cursor.execute("BEGIN")
#     105 # Rename tables
#
# File ~/anaconda3/envs/bertopicenv/lib/python3.9/encodings/utf_8.py:15, in decode(input, errors)
#      11 ### Codec APIs
#      13 encode = codecs.utf_8_encode
# ---> 15 def decode(input, errors='strict'):
#      16     return codecs.utf_8_decode(input, errors, True)
#      18 class IncrementalEncoder(codecs.IncrementalEncoder):
#
# KeyboardInterrupt:

# %%
for i, row in renamed_hierarchy_df.head(10).iterrows():
    print(row['parent_id'])

# %%
1

# %%
cols = []
count = 1
for column in renamed_hierarchy_df.columns:
    if column == 'parent_id':
        cols.append(f'parent_id{count}')
        count+=1
        continue
    cols.append(column)
renamed_hierarchy_df.columns = cols

# %%
renamed_hierarchy_df.isnull().mean()
# Out:
# Unnamed: 0              0.000000
# parent_id1              0.000000
# parent_name             0.000000
# child_storyline_list    0.000000
# child_left_id           0.501348
# child_left_name         0.501348
# child_right_id          0.501348
# child_right_name        0.501348
# distance                0.501348
# level                   0.001348
# num_docs                0.001348
# doc_list                0.001348
# parent_id2              0.970350
# outlier_count           0.970350
# total_count             0.970350
# outlier_percent         0.970350
# dtype: float64

# %%
renamed_hierarchy_df = renamed_hierarchy_df.rename(columns = {'parent_id1': 'parent_id'})

# %%
renamed_hierarchy_df.dtypes
# Out:
# Unnamed: 0                int64
# parent_id                 int64
# parent_name              object
# child_storyline_list     object
# child_left_id           float64
# child_left_name          object
# child_right_id          float64
# child_right_name         object
# distance                float64
# level                   float64
# num_docs                float64
# doc_list                 object
# parent_id2              float64
# outlier_count           float64
# total_count             float64
# outlier_percent         float64
# dtype: object

# %%
import ast

# %%
renamed_hierarchy_df['child_storyline_list'] = renamed_hierarchy_df['child_storyline_list'].apply(lambda x: ast.literal_eval(x))

# %%
from datetime import datetime

# %%
pd.isna(renamed_hierarchy_df.iloc[432].child_left_id)
# Out:
# True

# %%
renamed_hierarchy_df.sample(30)
# Out:
#      Unnamed: 0  parent_id                                        parent_name  \
# 738         738        367  367_yatharth_yatharth hospital_hospital_hospit...
# 380         380          9                         9_tcs_infosys_hcl_hcl tech
# 662         662        291                        291_alibaba_jack ma_ma_jack
# 253         253        487             toubro_larsen toubro_larsen_bags_order
# 553         553        182         182_formula_regression_variance_statistics
# 40           40        700  innerworth mind_innerworth_mind markets_mind_c...
# 712         712        341       341_titagarh_titagarh rail_rail_rail systems
# 341         341        399       standalone_2023 net_net sales_sales rs_sales
# 212         212        528            gdp_growth_gdp growth_economy_india gdp
# 296         296        444                ai_openai_chatgpt_altman_generative
# 560         560        189  189_mint hindustan_hindustan_hindustan unileve...
# 124         124        616  gainers losers_losers_gainers_check list_mint ...
# 251         251        489         credit_card_credit card_credit score_score
# 707         707        336          336_inclusion_indian bonds_jpmorgan_index
# 314         314        426                 nclt_insolvency_lessors_nclat_plea
# 619         619        248      248_rupee_rupee opens_dollar_asian currencies
# 318         318        422       2023 net_net sales_sales rs_standalone_sales
# 216         216        524           live blog_blog_price live_2023 mint_live
# 430         430         59  59_infra_infra standalone_infra consolidated_2...
# 411         411         40  40_tech standalone_tech consolidated_tech_2023...
# 556         556        185               185_yes bank_yes_mint yes_bank share
# 191         191        549       powergrid_mint powergrid_ultra cem_cem_ultra
# 657         657        286       286_savings_small savings_nsc_savings scheme
# 655         655        284          284_currency_history_exchange rates_works
# 715         715        344               344_home_house_buy house_buying home
# 438         438         67  67_making biggest_stocks making_biggest moves_...
# 628         628        257  257_forge_bharat forge_ramkrishna forgings_ram...
# 460         460         89       89_wheat_2023 geojit_picks report_agri picks
# 376         376          5                       5_oil_oil prices_opec_prices
# 459         459         88            88_havells_voltas_havells india_polycab
#
#                                   child_storyline_list  child_left_id  \
# 738                                                 []            NaN
# 380                                                 []            NaN
# 662                                                 []            NaN
# 253                                           [31, 70]           31.0
# 553                                                 []            NaN
# 40   [1, 14, 20, 23, 28, 33, 37, 44, 51, 54, 55, 61...          647.0
# 712                                                 []            NaN
# 341                                [0, 40, 43, 65, 76]           65.0
# 212                                          [16, 247]          247.0
# 296                                          [18, 183]          183.0
# 560                                                 []            NaN
# 124                               [105, 129, 214, 263]          481.0
# 251                               [193, 279, 305, 320]          279.0
# 707                                                 []            NaN
# 314                                          [62, 199]          199.0
# 619                                                 []            NaN
# 318         [0, 40, 43, 59, 65, 76, 83, 120, 149, 157]          419.0
# 216                                       [2, 75, 191]          191.0
# 430                                                 []            NaN
# 411                                                 []            NaN
# 556                                                 []            NaN
# 191                                    [283, 289, 326]          289.0
# 657                                                 []            NaN
# 655                                                 []            NaN
# 715                                                 []            NaN
# 438                                                 []            NaN
# 628                                                 []            NaN
# 460                                                 []            NaN
# 376                                                 []            NaN
# 459                                                 []            NaN
#
#                                        child_left_name  child_right_id  \
# 738                                                NaN             NaN
# 380                                                NaN             NaN
# 662                                                NaN             NaN
# 253  toubro_larsen toubro_larsen_finance holdings_t...            70.0
# 553                                                NaN             NaN
# 40                job_retirement_financial_work_hiring           696.0
# 712                                                NaN             NaN
# 341  chem_chem standalone_chem consolidated_fert_ch...           385.0
# 212   budget_fiscal deficit_deficit_fiscal_budget 2023            16.0
# 296             openai_altman_sam altman_sam_microsoft            18.0
# 560                                                NaN             NaN
# 124       bse_holiday_nse_remain closed_market holiday           539.0
# 251                  tcs_lrs_20 tcs_credit cards_cards           466.0
# 707                                                NaN             NaN
# 314           nclt_insolvency_nclat_plea_future retail            62.0
# 619                                                NaN             NaN
# 318       2023 net_net sales_sales rs_standalone_sales           149.0
# 216     idfc_idfc bank_mint idfc_idfc share_bank share           381.0
# 430                                                NaN             NaN
# 411                                                NaN             NaN
# 556                                                NaN             NaN
# 191          ultra cem_cem_ultra_mint ultra_cem closed           532.0
# 657                                                NaN             NaN
# 655                                                NaN             NaN
# 715                                                NaN             NaN
# 438                                                NaN             NaN
# 628                                                NaN             NaN
# 460                                                NaN             NaN
# 376                                                NaN             NaN
# 459                                                NaN             NaN
#
#                                       child_right_name  distance  level  \
# 738                                                NaN       NaN   10.0
# 380                                                NaN       NaN   13.0
# 662                                                NaN       NaN   27.0
# 253                  irb_kalpataru_infra_worth rs_nbcc  0.877703    9.0
# 553                                                NaN       NaN    8.0
# 40   innerworth_mind markets_innerworth mind_mind_c...  1.191498   14.0
# 712                                                NaN       NaN   10.0
# 341       standalone_2023 net_net sales_sales rs_sales  0.707392   14.0
# 212            gdp_growth_gdp growth_economy_india gdp  0.915730   19.0
# 296         ai_chatgpt_generative_generative ai_openai  0.820072   12.0
# 560                                                NaN       NaN    9.0
# 124  gainers losers_losers_gainers_mint gainers_los...  0.993100   10.0
# 251         credit_credit card_card_credit score_score  0.882458    8.0
# 707                                                NaN       NaN   21.0
# 314              lessors_aircraft_nclt_insolvency_dgca  0.779772   16.0
# 619                                                NaN       NaN    8.0
# 318  pharma standalone_pharma_pharma consolidated_p...  0.768055    9.0
# 216           live blog_blog_price live_2023 mint_live  0.911678    8.0
# 430                                                NaN       NaN   11.0
# 411                                                NaN       NaN   17.0
# 556                                                NaN       NaN    9.0
# 191  powergrid_mint powergrid_powergrid share_ntpc ...  0.940151   12.0
# 657                                                NaN       NaN   11.0
# 655                                                NaN       NaN    8.0
# 715                                                NaN       NaN   12.0
# 438                                                NaN       NaN   25.0
# 628                                                NaN       NaN   11.0
# 460                                                NaN       NaN   12.0
# 376                                                NaN       NaN   11.0
# 459                                                NaN       NaN    9.0
#
#      num_docs                                           doc_list  parent_id2  \
# 738      51.0  [5667, 6897, 10221, 10492, 14911, 16263, 23354...         NaN
# 380     774.0  [251, 364, 913, 965, 1203, 1293, 1418, 1781, 2...         NaN
# 662      72.0  [1401, 1554, 2614, 5215, 5384, 5642, 6497, 713...         NaN
# 253     633.0  [1, 120, 243, 344, 930, 1171, 1415, 1423, 2119...         NaN
# 553     120.0  [64, 719, 2225, 2745, 3287, 3998, 4988, 8528, ...         NaN
# 40    14136.0  [779, 2319, 3563, 7157, 19751, 20384, 20682, 2...         NaN
# 712      57.0  [620, 685, 5810, 9585, 12843, 14372, 20309, 22...         NaN
# 341    2814.0  [669, 948, 1057, 1689, 2047, 3350, 5700, 6104,...         NaN
# 212     644.0  [1479, 2683, 3269, 4123, 5445, 5579, 5761, 640...         NaN
# 296     661.0  [937, 2056, 2783, 3413, 3725, 5869, 6141, 6996...         NaN
# 560     116.0  [284, 2075, 2368, 2916, 5816, 5828, 5888, 6249...         NaN
# 124     540.0  [187, 674, 1101, 1694, 1877, 2796, 3032, 3250,...         NaN
# 251     320.0  [504, 1220, 2865, 3609, 5656, 6621, 7128, 7383...         NaN
# 707      58.0  [6019, 7526, 8507, 9924, 11362, 12683, 13251, ...         NaN
# 314     388.0  [256, 475, 3262, 4012, 6926, 7283, 8346, 9747,...         NaN
# 619      89.0  [2010, 9142, 11819, 12132, 14725, 14940, 16496...         NaN
# 318    3768.0  [746, 1192, 1426, 1492, 1646, 3464, 3490, 3678...         NaN
# 216    1593.0  [1245, 2107, 2582, 4777, 5318, 5655, 5974, 599...         NaN
# 430     279.0  [746, 1192, 1426, 1492, 1646, 3464, 3490, 3678...         NaN
# 411     332.0  [702, 833, 1460, 1816, 2361, 2741, 4543, 4727,...         NaN
# 556     117.0  [1374, 1528, 4253, 5474, 6503, 9786, 10096, 11...         NaN
# 191     207.0  [438, 745, 1702, 3746, 4205, 6297, 9692, 9971,...         NaN
# 657      74.0  [3029, 3276, 6018, 6143, 7915, 8300, 10744, 11...         NaN
# 655      74.0  [212, 1053, 1176, 2963, 3316, 4829, 7473, 9461...         NaN
# 715      56.0  [1953, 2292, 3430, 4871, 11777, 15475, 16972, ...         NaN
# 438     253.0  [868, 2428, 2535, 2628, 2781, 2954, 3112, 3715...         NaN
# 628      85.0  [3623, 7148, 8904, 9470, 9694, 15990, 17567, 1...         NaN
# 460     210.0  [1035, 1411, 1585, 2898, 3212, 3334, 3349, 404...         NaN
# 376     946.0  [295, 393, 464, 644, 775, 845, 871, 934, 973, ...         NaN
# 459     211.0  [302, 416, 418, 1290, 3465, 3636, 4432, 4923, ...         NaN
#
#      outlier_count  total_count  outlier_percent
# 738            NaN          NaN              NaN
# 380            NaN          NaN              NaN
# 662            NaN          NaN              NaN
# 253            NaN          NaN              NaN
# 553            NaN          NaN              NaN
# 40             NaN          NaN              NaN
# 712            NaN          NaN              NaN
# 341            NaN          NaN              NaN
# 212            NaN          NaN              NaN
# 296            NaN          NaN              NaN
# 560            NaN          NaN              NaN
# 124            NaN          NaN              NaN
# 251            NaN          NaN              NaN
# 707            NaN          NaN              NaN
# 314            NaN          NaN              NaN
# 619            NaN          NaN              NaN
# 318            NaN          NaN              NaN
# 216            NaN          NaN              NaN
# 430            NaN          NaN              NaN
# 411            NaN          NaN              NaN
# 556            NaN          NaN              NaN
# 191            NaN          NaN              NaN
# 657            NaN          NaN              NaN
# 655            NaN          NaN              NaN
# 715            NaN          NaN              NaN
# 438            NaN          NaN              NaN
# 628            NaN          NaN              NaN
# 460            NaN          NaN              NaN
# 376            NaN          NaN              NaN
# 459            NaN          NaN              NaN

# %%
renamed_hierarchy_df['child_left_id'] = renamed_hierarchy_df['child_left_id'].apply(lambda x: int(x) if pd.notna(x) else None)
renamed_hierarchy_df['child_right_id'] = renamed_hierarchy_df['child_right_id'].apply(lambda x: int(x) if pd.notna(x) else None)

# %%
with PostgresDatabaseOperation() as cursor:
    # first truncate the data in live table
    truncate_sql = f"""
            TRUNCATE TABLE cluster_hierarchy RESTART IDENTITY
    """
    cursor.execute(truncate_sql)

    # Insert the data in live and history tables
    insert_sql = f"""
        INSERT INTO cluster_hierarchy (parent_id, parent_name, child_storyline_list, child_left_id, child_left_name, child_right_id, child_right_name, clustering_run_id, created_at)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
    """

    history_sql = f"""
        INSERT INTO cluster_hierarchy_history (parent_id, parent_name, child_storyline_list, child_left_id, child_left_name, child_right_id, child_right_name, clustering_run_id, created_at)
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
    """
    current_time = datetime.now()
    for index, row in renamed_hierarchy_df.iterrows():
        if pd.isna(row['child_left_id']):
            child_left_id = None
            child_right_id = None
        else:
            child_left_id = int(row['child_left_id'])
            child_right_id = int(row['child_right_id'])
        cursor.execute(insert_sql, (row['parent_id'], row['parent_name'], row['child_storyline_list'], child_left_id, row['child_left_name'],
                                        child_right_id, row['child_right_name'], run_id, current_time))
        cursor.execute(history_sql, (row['parent_id'], row['parent_name'], row['child_storyline_list'], child_left_id, row['child_left_name'],
                                         child_right_id, row['child_right_name'], run_id, current_time))

# %%
renamed_hierarchy_df.child_left_id.max()
# Out:
# 737.0

# %%
# ClusteringSQL.insert_cluster_hierarchy(cluster_hierarchy_df=renamed_hierarchy_df,
#                                                clustering_run_id=run_id)

# %%
ClusteringSQL.insert_storyline_to_cluster_mapping(story_to_cluster_mapping=story_cluster_mapping, clustering_run_id=run_id)

# %%
story_embeddings = load_json_from_s3(run_id = run_id, json_file_name='story_embeddings')

# %%
int_story_embeddings = {}

# %%
for story in story_embeddings:
    int_story_embeddings[int(story)] = story_embeddings[story]

# %%
with PostgresDatabaseOperation() as cursor:
    truncate_sql = f"""
                    TRUNCATE TABLE story_embeddings RESTART IDENTITY
                    """
    cursor.execute(truncate_sql)

    insert_sql = f"""INSERT INTO story_embeddings (story_id, story_embedding, clustering_run_id)
                    VALUES (%s, %s, %s)
                    """
    # TODO: - can't ideally assume that -1 exists. should come from clustering run - refactor
    if -1 in story_embeddings:
        total = len(int_story_embeddings) - 1
    else:
        total = len(int_story_embeddings)
    for i in range(total-1):
        story_embedding = list(int_story_embeddings[i])
        cursor.execute(insert_sql, (i, story_embedding, run_id))

# %% [markdown]
# ### update topic preferences

# %%
from src.topics.TopicClusterMapping import TopicClusterMapping

# %%
with initialize(config_path="../../conf"):
    # Compose the configuration
    topic_cfg = compose(config_name="TopicClusterMapping.yaml")

# %%
tcm = TopicClusterMapping(clustering_run_id=run_id, bertopic_model=bertopic_model, cfg=topic_cfg)

# %%
tcm.recompute_preferences_for_all_topics()

# %%
import sys

# %%
import pickle

# %%
with open('bertopic_model.pkl', 'wb') as f:
    pickle.dump(bertopic_model, f)

# %%
sys.getsizeof(bertopic_model.probabilities_)
# Out:
# 128

# %%
bertopic_model.probabilities_ = None

# %%
bertopic_model.topic_embeddings_ = None

# %%
bertopic_model.topic_representations_ = None

# %%
bertopic_model.topics_ = None

# %%
with open('hdbscan_model.pkl', 'wb') as f:
    pickle.dump(bertopic_model.hdbscan_model, f)

# %%
with open('umap_model.pkl', 'wb') as f:
    pickle.dump(bertopic_model.umap_model, f)

# %%
len(embs[0])
# Out:
# 10

# %%
k = np.random.rand(1024)

# %%
graph = bertopic_model.umap_model.graph_

# %%
bertopic_model.umap_model.graph_ = None

# %%
bertopic_model.umap_model._raw_data = [bertopic_model.umap_model._raw_data[0]]

# %%
bertopic_model.umap_model.disconnection_distance

# %%
bertopic_model.topic_embeddings_
# Out:
# array([[ 3.2104e-02,  1.3843e-01, -9.1187e-02, ..., -8.8196e-02,
#         -1.5710e-01,  1.4618e-02],
#        [-9.1171e-03,  3.4088e-02, -2.2614e-02, ..., -1.0918e-02,
#         -5.4871e-02, -1.8738e-02],
#        [-8.4496e-04,  1.0614e-01, -1.8978e-03, ..., -2.9007e-02,
#         -1.1804e-01, -3.4790e-02],
#        ...,
#        [-1.1055e-02,  4.6570e-02, -1.7258e-02, ..., -3.8666e-02,
#         -2.5864e-02,  7.0632e-05],
#        [-4.3671e-02,  1.4014e-01, -4.4983e-02, ..., -5.7098e-02,
#         -2.2754e-01, -1.7609e-02],
#        [ 4.7821e-02,  7.8735e-02, -3.3630e-02, ..., -5.5969e-02,
#         -3.4454e-02, -3.3173e-02]], dtype=float16)
