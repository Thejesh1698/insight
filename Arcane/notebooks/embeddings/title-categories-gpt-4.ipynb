# %%
import re
import pandas as pd
import numpy as np
import openai
import json
import tiktoken
from concurrent.futures import ThreadPoolExecutor, as_completed
import time

# %%
def calculate_tokens(text, encoder):  # Placeholder for your actual token calculation function
    # Your implementation will go here.
    return len(encoder.encode(text))  # Example: counting characters as tokens

def truncate_text_for_token_limit(text,encoder, token_limit):
    # First, check if the whole text is under the token limit
    if calculate_tokens(text, encoder) <= token_limit:
        return text  # The entire text is within the limit

    def is_under_limit(index):
        # Use the provided function to calculate tokens for the substring
        return calculate_tokens(text[:index], encoder) <= token_limit

    left, right = 0, len(text)
    valid_limit = 0  # This will hold the index of the last valid token position

    # Binary search to find the token limit
    while left <= right:
        mid = (left + right) // 2  # Find the midpoint
        if is_under_limit(mid):
            # If the midpoint is under the limit, store it as a valid limit
            valid_limit = mid
            left = mid + 1  # Move the left boundary to the right
        else:
            right = mid - 1  # Move the right boundary to the left

    # Find the last space before the valid_limit to ensure we're at a word boundary
    space_index = text.rfind(' ', 0, valid_limit)
    if space_index == -1:
        # If there's no space, we've hit the start of the text
        return text[:valid_limit]  # Return up to the valid limit even if mid-word

    # Return the text up to the last word within the token limit
    return text[:space_index]

# %%
parent_folder = '/Users/username/Desktop/ML/Recommendations/arcane/'
from hydra import compose, initialize
import os
import xml.etree.ElementTree as ET

tree = ET.parse('../../conf/application.run.xml')
root = tree.getroot()

envs_element = root.find('./configuration/envs')
for variable in envs_element.findall('env'):
    name = variable.get('name')
    value = variable.get('value')
    os.environ[name] = value

import sys
sys.path.append('/Users/username/Desktop/ML/Recommendations/arcane/')

import numpy as np
import pandas as pd
import json
from sql.articles.MongoDBArticle import MongoDBArticle
from sql.PostgresDatabaseOperation import PostgresDatabaseOperation

# %%
def fetch_documents_after_date(min_published_date):
    query = {"is_premium_article": False, "published_time": {"$gt": min_published_date}, 'content_type': 'ARTICLE'}
    projection = {"_id": 1, "source_id": 1, "title": 1, "tags": 1, "cleaned_text": 1}
    collection = MongoDBArticle.get_collection()
    documents = list(collection.find(query, projection))
    return documents

# %%
feb_articles = fetch_documents_after_date('2024-02-01')

# %%
len(feb_articles)
# Out:
# 41148

# %%
for x in feb_articles:
    # x.pop('_id')
    x.pop('source_id')

# %%
feb_articles[0]
# Out:
# {'cleaned_text': 'SUMMARY These proposals are in addition to the INR 22,516 Cr chip assembly plant set up by US-based memory chip maker Micron The government has given approval to the Semicon India program, allocating a total budget of INR 76,000 Cr for the development of the semiconductor The shift towards the Indian semiconductor market also appears promising, as it is anticipated to reach a market size of $55 Bn by 2026 FOLLOW US FOLLOW US Added to Saved Stories in Login VIEW SAVED STORIES The government has received four proposals for building semiconductor manufacturing plants and 13 for chip assembly units, the Parliament was informed. These proposals are in addition to the INR 22,516 Cr chip assembly plant set up by US-based memory chip maker Micron, Rajeev Chandrasekhar, Minister of State for Electronics and IT,  said in a written reply in the Lok Sabha on Wednesday (February 7). “Four proposals have been received for setting up semiconductor fabs and additional 13 proposals have been received for setting up compound semiconductor fabs and ATMP ( assembly, testing, marking and packaging) facilities,” the minister said. The government has given approval to the Semicon India programme, allocating a total budget of INR 76,000 Cr for the development of the semiconductor and display manufacturing ecosystem within the country. The programme aims to offer financial assistance to companies investing in the ecosystems of semiconductors, display manufacturing, and design. Earlier, the MoS said the proposed India semiconductor research centre (ISRC) will lead in developing India’s capabilities in the semiconductor space. Reiterating the government’s vision, the MoS said India has to become a leader in the semiconductor research space. The global semiconductor landscape is largely dominated by a handful of companies operating out of Taiwan, South Korea and the US. This has led to an overdependence of India on a few companies for these critical components which now form the backbone of all key products from smartphones to cars. As a result, the union government has rolled out a red carpet for global semiconductor players to Make in India and help their Indian partners learn the ropes of the trade and leverage intellectual properties. Be it MeitY’s mega $10 Bn commitment towards the India Semiconductor Mission (ISM) or the design-linked-incentives (DLIs), the Centre has left no stone unturned to scale the local semiconductor manufacturing. Meanwhile, from Micron Technology to Foxconn have made a beeline for India and are looking to set up a base in the country. At the heart of this India pivot also seems to be the lucrative Indian semiconductor market, which is projected to grow to a market size of $55 Bn by 2026 .',
#  'tags': None,
#  'title': 'Govt Secured 4 Proposals For Setting Up Semiconductor Plants, 13 For Chip Assembly Units',
#  'article_id': '65c47c02da99411d47477436',
#  'masked_article_id': '411d47477436c47c02da99'}

# %%
prompt = '''You are to categorize financial and business news article titles into one of 5 distinct categories based on the article's primary focus and intent. This task requires understanding the context, intent behind the article, its impact, and the target audience.
1. Evaluate Context and Intent: Consider the setting and purpose of the article. Is it reporting news, offering advice, analyzing trends, or discussing impacts of policies?
2. **Determine Impact and Audience**:
    - **company_business_news**: Articles detailing initiatives and actions by companies. This includes any operational news, mergers, acquisitions, leadership changes. This is all non financial news of companies. Specific financial news of companies will come under ‘market_news’.
    - **market_news**: Articles aimed at providing updates on financial markets or insights on investment strategies, market analysis, or reviews of financial products, targeting investors or financial analysts and financial performance of companies. Targeted at active investors. 
    - **economic_policies_trends**: Articles analyzing or reporting on government policies, regulations, and their implications for the economy, businesses, or sectors, of interest to business leaders, policymakers, and informed citizens.
    - **personal_finance**: Articles offering guidance on individual financial management, such as investment for personal goals, savings, taxation, and insurance, directly targeting individual consumers and passive investors. 
    - **non_financial**: Article isn’t a financial article and talks about general politics, movies, sports or any other non financial and business news
3. **Consider the Primary Audience**:
   - Reflect on who will benefit most from the article. company_news is for industry insiders, market strategies for investors, policy impact for those interested in economic and business implications, and personal finance for the general public seeking financial advice.
Your answer must be only one of corporate_developments, market_strategies, economic_policies_trends, personal_finance, non_financial without any preamble or postamble
You are provided with 500 titles along with their article_ids in the format [{"id": "", "title": }]
answer in the format of [{"id": "", "title": "", "category": ""}]. Make sure your answer is directly the list of jsons. I want to parse it using json.loads() and it should work as expected. Also make sure to maintain the same title against the correct id
|titles|
'''

# %%
def mask_article_id(art_id):
    first_part = art_id[2:12]
    second_part = art_id[12:]
    masked = second_part + first_part
    return masked

# %%
def unmask_article_id(art_id):
    original_first_part = art_id[12:]
    original_second_part = art_id[:12]
    unmasked = '65' + original_first_part + original_second_part
    return unmasked

# %%
for art in feb_articles:
    art['article_id'] = str(art['_id'])
    art['masked_article_id'] = mask_article_id(art['article_id'])

# %%
# training_articles = np.random.choice(feb_articles, 8000)

# training_articles = list(training_articles)

# test_articles = np.random.choice([x for x in feb_articles if x not in training_articles], 2000)

# test_articles = list(test_articles)

# all_articles = list(training_articles) + list(test_articles)

# %%
# with open('title_category_training.json', 'w', encoding='utf-8') as f:
#     json.dump(training_articles, f)

# with open('title_category_test.json', 'w', encoding='utf-8') as f:
#     json.dump(test_articles, f)

# %% [markdown]
# ### Creation of prompts

# %%
chunk_size = 100
num_chunks = int(len(all_articles)/chunk_size)

for i in range(num_chunks):
    chunk = all_articles[chunk_size*i:chunk_size*(i+1)]
    chunk_json_list = [{'id': x['article_id'], 'title': x['title']} for x in chunk]
    chunk_string = json.dumps(chunk_json_list)
    cur_chunk_propmt = prompt + chunk_string

# %%
cur_chunk_propmt
# Out:
# 'You are to categorize financial and business news article titles into one of 5 distinct categories based on the article\'s primary focus and intent. This task requires understanding the context, intent behind the article, its impact, and the target audience.\n1. Evaluate Context and Intent: Consider the setting and purpose of the article. Is it reporting news, offering advice, analyzing trends, or discussing impacts of policies?\n2. **Determine Impact and Audience**:\n    - **company_business_news**: Articles detailing initiatives and actions by companies. This includes any operational news, mergers, acquisitions, leadership changes. This is all non financial news of companies. Specific financial news of companies will come under ‘market_news’.\n    - **market_news**: Articles aimed at providing updates on financial markets or insights on investment strategies, market analysis, or reviews of financial products, targeting investors or financial analysts and financial performance of companies. Targeted at active investors. \n    - **economic_policies_trends**: Articles analyzing or reporting on government policies, regulations, and their implications for the economy, businesses, or sectors, of interest to business leaders, policymakers, and informed citizens.\n    - **personal_finance**: Articles offering guidance on individual financial management, such as investment for personal goals, savings, taxation, and insurance, directly targeting individual consumers and passive investors. \n    - **non_financial**: Article isn’t a financial article and talks about general politics, movies, sports or any other non financial and business news\n3. **Consider the Primary Audience**:\n   - Reflect on who will benefit most from the article. company_news is for industry insiders, market strategies for investors, policy impact for those interested in economic and business implications, and personal finance for the general public seeking financial advice.\nYour answer must be only one of corporate_developments, market_strategies, economic_policies_trends, personal_finance, non_financial without any preamble or postamble\nYou are provided with 500 titles along with their article_ids in the format [{"id": "", "title": }]\nanswer in the format of [{"id": "", "title": "", "category": ""}]. Make sure your answer is directly the list of jsons. I want to parse it using json.loads() and it should work as expected. Also make sure to maintain the same title against the correct id\n|titles|\n[{"id": "65c32a9ac119ff6e57a4414e", "title": "Greaves Retail\'s multi-brand AutoEVMart partners with Zero21"}, {"id": "65cc2d1e06df7536a8f68774", "title": "Barclays VP sues for $290,000, alleging discrimination"}, {"id": "65c605c3f4fc8477f2ed657f", "title": "RBI mandates lenders to furnish Key Fact Statement: What is KFS and how will it bring transparency? Experts explain | Mint"}, {"id": "65cd7ed5abb31841109cda5e", "title": "Breaking Stigmas About STEM"}, {"id": "65c9fa4cf4fc8477f2ed8093", "title": "Uflex Standalone December 2023 Net Sales at Rs 1,648.67 crore, down 3.3% Y-o-Y"}, {"id": "65c1d2e6c119ff6e57a3f5c6", "title": "mPrest Selected as DERMS Provider for EDF Renewables"}, {"id": "65c1d733c119ff6e57a42d90", "title": "The Scotts Miracle-Gro Foundation and Alliance for Water Efficiency Partner to Support Water Usage Research and Education"}, {"id": "65cc2d0b06df7536a8f6867f", "title": "Flipboard just brought over 1,000 of its social magazines to Mastodon and the fediverse"}, {"id": "65ced02aabb31841109ceb0a", "title": "Stryten Energy to Highlight the Power of Battery Energy Storage Systems at NAATBatt 2024"}, {"id": "65cc2d5106df7536a8f68a0e", "title": "Millions struggle with student loan repayments amid stubborn inflation"}, {"id": "65cadbfcf4fc8477f2ed8b96", "title": "Mankind Pharma wants to enter export market of niche products"}, {"id": "65c1d739c119ff6e57a42de0", "title": "G-7 Eye Russian Assets as Collateral to Raise Funds for Ukraine"}, {"id": "65c595d46 ...

# %%
from datetime import datetime
from tqdm.notebook import tqdm
import json
from openai import OpenAI

client = OpenAI(api_key='')

# %%
model = 'gpt-4'

# %%
r = client.chat.completions.create(model = 'gpt-4', messages = [{'role': 'system', 'content': prompt}, {'role': 'user', 'content': chunk_string}])

# %%
r.usage.completion_tokens, r.usage.prompt_tokens
# Out:
# (3365, 4828)

# %%
corrected_r = r.choices[0].message.content[:-13] + ']'

# %%
k = json.loads(corrected_r)

# %%
len(k)
# Out:
# 66

# %%
chunk_dict = {x['article_id']: x for x in chunk}

# %%
k
# Out:
# [{'id': '65c32a9ac119ff6e57a4414e',
#   'title': "Greaves Retail's multi-brand AutoEVMart partners with Zero21",
#   'category': 'company_business_news'},
#  {'id': '65cc2d1e06df7536a8f68774',
#   'title': 'Barclays VP sues for $290,000, alleging discrimination',
#   'category': 'company_business_news'},
#  {'id': '65c605c3f4fc8477f2ed657f',
#   'title': 'RBI mandates lenders to furnish Key Fact Statement: What is KFS and how will it bring transparency? Experts explain | Mint',
#   'category': 'economic_policies_trends'},
#  {'id': '65cd7ed5abb31841109cda5e',
#   'title': 'Breaking Stigmas About STEM',
#   'category': 'non_financial'},
#  {'id': '65c9fa4cf4fc8477f2ed8093',
#   'title': 'Uflex Standalone December 2023 Net Sales at Rs 1,648.67 crore, down 3.3% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c1d2e6c119ff6e57a3f5c6',
#   'title': 'mPrest Selected as DERMS Provider for EDF Renewables',
#   'category': 'company_business_news'},
#  {'id': '65c1d733c119ff6e57a42d90',
#   'title': 'The Scotts Miracle-Gro Foundation and Alliance for Water Efficiency Partner to Support Water Usage Research and Education',
#   'category': 'company_business_news'},
#  {'id': '65cc2d0b06df7536a8f6867f',
#   'title': 'Flipboard just brought over 1,000 of its social magazines to Mastodon and the fediverse',
#   'category': 'company_business_news'},
#  {'id': '65ced02aabb31841109ceb0a',
#   'title': 'Stryten Energy to Highlight the Power of Battery Energy Storage Systems at NAATBatt 2024',
#   'category': 'company_business_news'},
#  {'id': '65cc2d5106df7536a8f68a0e',
#   'title': 'Millions struggle with student loan repayments amid stubborn inflation',
#   'category': 'personal_finance'},
#  {'id': '65cadbfcf4fc8477f2ed8b96',
#   'title': 'Mankind Pharma wants to enter export market of niche products',
#   'category': 'company_business_news'},
#  {'id': '65c1d739c119ff6e57a42de0',
#   'title': 'G-7 Eye Russian Assets as Collateral to Raise Funds for Ukraine',
#   'category': 'economic_policies_trends'},
#  {'id': '65c595d461e5050757966cf9',
#   'title': 'FRN Variable Rate Fix',
#   'category': 'market_news'},
#  {'id': '65c838a2f4fc8477f2ed76e2',
#   'title': 'Insiders See US$1.25m Investment In Immunome Jump Last Week',
#   'category': 'market_news'},
#  {'id': '65cc2d0506df7536a8f6862e',
#   'title': 'The Fashion and Management Missteps That Left Express Clinging to Solvency',
#   'category': 'company_business_news'},
#  {'id': '65cc9d4babb31841109ccf28',
#   'title': 'Anupam Rasayan Consolidated December 2023 Net Sales at Rs 295.52 crore, down 22.79% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c47c15da99411d474774be',
#   'title': 'Vinayak Vanijya Standalone December 2023 Net Sales at Rs 0.06 crore, up 96.43% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c1d5ffc119ff6e57a41dc4',
#   'title': '4 types of debt you can consolidate',
#   'category': 'personal_finance'},
#  {'id': '65c4b45461e50507579662ed',
#   'title': 'EPL Consolidated December 2023 Net Sales at Rs 975.10 crore, up 3.2% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65bc9315f3aa2a77a58c0284',
#   'title': "Devyani International Q3: KFC operator's net profit falls 87% to Rs 9.6 crore",
#   'category': 'market_news'},
#  {'id': '65cb13c0f4fc8477f2ed8f83',
#   'title': 'Several Insiders Invested In Fortress Minerals Flagging Positive News',
#   'category': 'market_news'},
#  {'id': '65c9fa88f4fc8477f2ed8225',
#   'title': 'Nvidia CEO says tech advances will keep AI cost in check',
#   'category': 'company_business_news'},
#  {'id': '65c6e744f4fc8477f2ed6e5e',
#   'title': 'How to Boost Your Portfolio with Top Oils-Energy Stocks Set to Beat Earnings',
#   'category': 'market_news'},
#  {'id': '65cc6522abb31841109ccdb2',
#   'title': 'Suumaya Ind. Standalone December 2023 Net Sales at Rs 1,114.08 crore, up 1414.31% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c2f2bcc119ff6e57a43ba7',
#   'title': 'Gladstone Investment (GAIN) Q3 Earnings: Taking a Look at Key Metrics Versus Estimates',
#   'category': 'market_news'},
#  {'id': '65ced077abb31841109ceefd',
#   'title': 'AMN Healthcare (AMN) Q4 Earnings: Taking a Look at Key Metrics Versus Estimates',
#   'category': 'market_news'},
#  {'id': '65cdeee7abb31841109ce28f',
#   'title': 'Rajshree Sugars Standalone December 2023 Net Sales at Rs 136.73 crore, down 1.66% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65cc9d57abb31841109ccfb5',
#   'title': 'Shri Bajrang Standalone December 2023 Net Sales at Rs 124.19 crore, up 169.02% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c1d63bc119ff6e57a420d3',
#   'title': 'Why Monster Beverage (MNST) Dipped More Than Broader Market Today',
#   'category': 'market_news'},
#  {'id': '65c5959b61e5050757966a08',
#   'title': 'Form 8.3 - Smart Metering Systems plc',
#   'category': 'market_news'},
#  {'id': '65ced06fabb31841109cee87',
#   'title': 'ExxonMobil Obtains Exemption from Canadian Oil and Gas Reporting Obligations',
#   'category': 'economic_policies_trends'},
#  {'id': '65c1d759c119ff6e57a42f8c',
#   'title': 'AM Best Places Credit Ratings for Several Subsidiaries of The Cigna Group Under Review with Developing Implications',
#   'category': 'company_business_news'},
#  {'id': '65cd7ea2abb31841109cd7e0',
#   'title': 'Why Upstart Stock Fell Sharply Today',
#   'category': 'market_news'},
#  {'id': '65cc651aabb31841109ccd39',
#   'title': 'Trade Wings Standalone December 2023 Net Sales at Rs 52.48 crore, up 7.77% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c2f2eac119ff6e57a43e01',
#   'title': 'Small business acquisitions leveled off in 2023 as interest rates climbed, but 2024 looks better',
#   'category': 'economic_policies_trends'},
#  {'id': '65cdeef7abb31841109ce330',
#   'title': 'Supra Pacific Financial Services standalone net profit rises 55.17% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65c44432da99411d47476dbf',
#   'title': 'Building Cyber Safety Into the School Curriculum',
#   'category': 'non_financial'},
#  {'id': '65c83850f4fc8477f2ed73db',
#   'title': 'Sakthi Finance standalone net profit rises 36.71% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65c989caf4fc8477f2ed78dd',
#   'title': 'Godrej Properties Share Price Live blog for 12 Feb 2024 | Mint',
#   'category': 'market_news'},
#  {'id': '65c595ca61e5050757966c70',
#   'title': 'Arm CEO talks growth as stock rallies on AI-fueled demand',
#   'category': 'company_business_news'},
#  {'id': '65c1d47ec119ff6e57a40a44',
#   'title': 'Casella Waste Systems, Inc. to Host Conference Call on Its Fourth Quarter 2023 Results',
#   'category': 'company_business_news'},
#  {'id': '65cecfecabb31841109ce710',
#   'title': 'Shashijit Infraprojects standalone net profit declines 50.00% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65cdb694abb31841109cdf9c',
#   'title': 'Shree Salasar Consolidated December 2023 Net Sales at Rs 2.03 crore, up 287.61% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c9fa54f4fc8477f2ed80e5',
#   'title': 'Kennametal Standalone December 2023 Net Sales at Rs 270.80 crore, down 1.46% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c8384df4fc8477f2ed73a0',
#   'title': 'Abhinav Capital Services standalone net profit rises 252.17% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65c6e77cf4fc8477f2ed716e',
#   'title': 'Petroperu Will Make All Payments to Bondholders, Minister Says',
#   'category': 'economic_policies_trends'},
#  {'id': '65c2f28fc119ff6e57a4394d',
#   'title': 'A Mississippi poultry plant is being sued by a woman whose 16-year-old son died working there',
#   'category': 'company_business_news'},
#  {'id': '65c6e6d5f4fc8477f2ed6986',
#   'title': 'Cremica Agro Foods standalone net profit rises 300.00% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65c08781c119ff6e57a3f009',
#   'title': 'Apeejay Surrendra Park Hotels IPO: Retail portion fully booked within hours of opening; check latest GMP, other details | Mint',
#   'category': 'market_news'},
#  {'id': '65c44494da99411d474772b1',
#   'title': 'Globe Life (GL) Reports Q4 Earnings: What Key Metrics Have to Say',
#   'category': 'market_news'},
#  {'id': '65cadbe2f4fc8477f2ed8a2b',
#   'title': 'KBRA Assigns Preliminary Ratings to Morgan Stanley Residential Mortgage Loan Trust 2024-INV1 (MSRM 2024-INV1)',
#   'category': 'market_news'},
#  {'id': '65ced04fabb31841109ceced',
#   'title': 'Inviting the AI-powered 5G Era, GIGABYTE will Present Next-Gen Servers for AI/HPC, Telecom, and Green Computing Solutions at MWC 2024',
#   'category': 'company_business_news'},
#  {'id': '65c44419da99411d47476c6e',
#   'title': 'Sleep Doctor partners with Airway Management to offer myTAP® Oral Appliance',
#   'category': 'company_business_news'},
#  {'id': '65cd7f00abb31841109cdc99',
#   'title': 'Bullish brokerage notes bolster PSU stocks higher on Wednesday',
#   'category': 'market_news'},
#  {'id': '65cc2cdb06df7536a8f6849b',
#   'title': "State-backed Oil India's third-quarter profit falls on lower crude prices",
#   'category': 'market_news'},
#  {'id': '65cf083babb31841109cf4d7',
#   'title': 'Global Apiculture Strategic Business Report 2024-2030: FlowT Hive Revolutionizes Honey Harvesting',
#   'category': 'market_news'},
#  {'id': '65c1d909c119ff6e57a433d7',
#   'title': "India's IOC sees growth in gasoline, diesel sales in FY2024/2025",
#   'category': 'economic_policies_trends'},
#  {'id': '65c4448eda99411d47477261',
#   'title': 'Aspire at Sage Hill: Melcom Homes promotes sustainable luxury with new multi-family development',
#   'category': 'company_business_news'},
#  {'id': '65cecffbabb31841109ce88e',
#   'title': 'Space Incubatrics Technologies reports consolidated net profit of Rs 0.04 crore in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65cadbd4f4fc8477f2ed8969',
#   'title': 'Great Inflation Hedge Unwind Sees TIPS ETFs Lose $43 Billion',
#   'category': 'economic_policies_trends'},
#  {'id': '65cd7e74abb31841109cd54c',
#   'title': 'NINtec Systems standalone net profit rises 182.64% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65cadbb4f4fc8477f2ed87c8',
#   'title': '2 Healthcare Stocks That Could Help Set You Up for Life',
#   'category': 'market_news'},
#  {'id': '65c1d474c119ff6e57a409c3',
#   'title': 'John Lewis denies blocking staff from joining union ahead of mass job cuts',
#   'category': 'company_business_news'},
#  {'id': '65cadba7f4fc8477f2ed8715',
#   'title': '\u200b\u200bStriking A Chord: Investors Tune Into The Lucrative Harmony Of Music Memorabilia',
#   'category': 'market_news'},
#  {'id': '65cdef10abb31841109ce458',
#   'title': 'Best Income Stocks to Buy for February 15th',
#   'category': 'market_news'},
#  {'id': '65c1d6b8c119ff6e57a4274a',
#   'title': 'Why Atlassian Stock Got Hammered Today',
#   'category': 'market_news'}]

# %% [markdown]
# #### Validating if the mapping is correct

# %%
for x in k:
    i_d = x['id']
    assert chunk_dict[i_d]['title'] == x['title']

# %% [markdown]
# #### Trying with gpt4 turbo

# %%
model2 = 'gpt-4-0125-preview'

# %%
r_turbo = client.chat.completions.create(model = model2, messages = [{'role': 'system', 'content': prompt}, {'role': 'user', 'content': chunk_string}])

# %%
# Out:
# ', {"id": "65c1d46ac119ff6e57a40942", "title": "Meta Reports Fourth Quarter and Full Year 2023'

# %%
r_turbo.choices[0].message.content[-93:] + ']'
# Out:
# ', {"id": "65c1d46ac119ff6e57a40942", "title": "Meta Reports Fourth Quarter and Full Year 2023]'

# %%
k_turbo = json.loads(r_turbo.choices[0].message.content[:-93] + ']')

# %%
k_turbo
# Out:
# [{'id': '65c32a9ac119ff6e57a4414e',
#   'title': "Greaves Retail's multi-brand AutoEVMart partners with Zero21",
#   'category': 'company_business_news'},
#  {'id': '65cc2d1e06df7536a8f68774',
#   'title': 'Barclays VP sues for $290,000, alleging discrimination',
#   'category': 'company_business_news'},
#  {'id': '65c605c3f4fc8477f2ed657f',
#   'title': 'RBI mandates lenders to furnish Key Fact Statement: What is KFS and how will it bring transparency? Experts explain | Mint',
#   'category': 'economic_policies_trends'},
#  {'id': '65cd7ed5abb31841109cda5e',
#   'title': 'Breaking Stigmas About STEM',
#   'category': 'non_financial'},
#  {'id': '65c9fa4cf4fc8477f2ed8093',
#   'title': 'Uflex Standalone December 2023 Net Sales at Rs 1,648.67 crore, down 3.3% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c1d2e6c119ff6e57a3f5c6',
#   'title': 'mPrest Selected as DERMS Provider for EDF Renewables',
#   'category': 'company_business_news'},
#  {'id': '65c1d733c119ff6e57a42d90',
#   'title': 'The Scotts Miracle-Gro Foundation and Alliance for Water Efficiency Partner to Support Water Usage Research and Education',
#   'category': 'company_business_news'},
#  {'id': '65cc2d0b06df7536a8f6867f',
#   'title': 'Flipboard just brought over 1,000 of its social magazines to Mastodon and the fediverse',
#   'category': 'company_business_news'},
#  {'id': '65ced02aabb31841109ceb0a',
#   'title': 'Stryten Energy to Highlight the Power of Battery Energy Storage Systems at NAATBatt 2024',
#   'category': 'company_business_news'},
#  {'id': '65cc2d5106df7536a8f68a0e',
#   'title': 'Millions struggle with student loan repayments amid stubborn inflation',
#   'category': 'economic_policies_trends'},
#  {'id': '65cadbfcf4fc8477f2ed8b96',
#   'title': 'Mankind Pharma wants to enter export market of niche products',
#   'category': 'company_business_news'},
#  {'id': '65c1d739c119ff6e57a42de0',
#   'title': 'G-7 Eye Russian Assets as Collateral to Raise Funds for Ukraine',
#   'category': 'economic_policies_trends'},
#  {'id': '65c595d461e5050757966cf9',
#   'title': 'FRN Variable Rate Fix',
#   'category': 'market_news'},
#  {'id': '65c838a2f4fc8477f2ed76e2',
#   'title': 'Insiders See US$1.25m Investment In Immunome Jump Last Week',
#   'category': 'market_news'},
#  {'id': '65cc2d0506df7536a8f6862e',
#   'title': 'The Fashion and Management Missteps That Left Express Clinging to Solvency',
#   'category': 'market_news'},
#  {'id': '65cc9d4babb31841109ccf28',
#   'title': 'Anupam Rasayan Consolidated December 2023 Net Sales at Rs 295.52 crore, down 22.79% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c47c15da99411d474774be',
#   'title': 'Vinayak Vanijya Standalone December 2023 Net Sales at Rs 0.06 crore, up 96.43% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c1d5ffc119ff6e57a41dc4',
#   'title': '4 types of debt you can consolidate',
#   'category': 'personal_finance'},
#  {'id': '65c4b45461e50507579662ed',
#   'title': 'EPL Consolidated December 2023 Net Sales at Rs 975.10 crore, up 3.2% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65bc9315f3aa2a77a58c0284',
#   'title': "Devyani International Q3: KFC operator's net profit falls 87% to Rs 9.6 crore",
#   'category': 'market_news'},
#  {'id': '65cb13c0f4fc8477f2ed8f83',
#   'title': 'Several Insiders Invested In Fortress Minerals Flagging Positive News',
#   'category': 'market_news'},
#  {'id': '65c9fa88f4fc8477f2ed8225',
#   'title': 'Nvidia CEO says tech advances will keep AI cost in check',
#   'category': 'company_business_news'},
#  {'id': '65c6e744f4fc8477f2ed6e5e',
#   'title': 'How to Boost Your Portfolio with Top Oils-Energy Stocks Set to Beat Earnings',
#   'category': 'personal_finance'},
#  {'id': '65cc6522abb31841109ccdb2',
#   'title': 'Suumaya Ind. Standalone December 2023 Net Sales at Rs 1,114.08 crore, up 1414.31% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c2f2bcc119ff6e57a43ba7',
#   'title': 'Gladstone Investment (GAIN) Q3 Earnings: Taking a Look at Key Metrics Versus Estimates',
#   'category': 'market_news'},
#  {'id': '65ced077abb31841109ceefd',
#   'title': 'AMN Healthcare (AMN) Q4 Earnings: Taking a Look at Key Metrics Versus Estimates',
#   'category': 'market_news'},
#  {'id': '65cdeee7abb31841109ce28f',
#   'title': 'Rajshree Sugars Standalone December 2023 Net Sales at Rs 136.73 crore, down 1.66% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65cc9d57abb31841109ccfb5',
#   'title': 'Shri Bajrang Standalone December 2023 Net Sales at Rs 124.19 crore, up 169.02% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c1d63bc119ff6e57a420d3',
#   'title': 'Why Monster Beverage (MNST) Dipped More Than Broader Market Today',
#   'category': 'market_news'},
#  {'id': '65c5959b61e5050757966a08',
#   'title': 'Form 8.3 - Smart Metering Systems plc',
#   'category': 'market_news'},
#  {'id': '65ced06fabb31841109cee87',
#   'title': 'ExxonMobil Obtains Exemption from Canadian Oil and Gas Reporting Obligations',
#   'category': 'market_news'},
#  {'id': '65c1d759c119ff6e57a42f8c',
#   'title': 'AM Best Places Credit Ratings for Several Subsidiaries of The Cigna Group Under Review with Developing Implications',
#   'category': 'market_news'},
#  {'id': '65cd7ea2abb31841109cd7e0',
#   'title': 'Why Upstart Stock Fell Sharply Today',
#   'category': 'market_news'},
#  {'id': '65cc651aabb31841109ccd39',
#   'title': 'Trade Wings Standalone December 2023 Net Sales at Rs 52.48 crore, up 7.77% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c2f2eac119ff6e57a43e01',
#   'title': 'Small business acquisitions leveled off in 2023 as interest rates climbed, but 2024 looks better',
#   'category': 'economic_policies_trends'},
#  {'id': '65cdeef7abb31841109ce330',
#   'title': 'Supra Pacific Financial Services standalone net profit rises 55.17% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65c44432da99411d47476dbf',
#   'title': 'Building Cyber Safety Into the School Curriculum',
#   'category': 'non_financial'},
#  {'id': '65c83850f4fc8477f2ed73db',
#   'title': 'Sakthi Finance standalone net profit rises 36.71% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65c989caf4fc8477f2ed78dd',
#   'title': 'Godrej Properties Share Price Live blog for 12 Feb 2024 | Mint',
#   'category': 'market_news'},
#  {'id': '65c595ca61e5050757966c70',
#   'title': 'Arm CEO talks growth as stock rallies on AI-fueled demand',
#   'category': 'company_business_news'},
#  {'id': '65c1d47ec119ff6e57a40a44',
#   'title': 'Casella Waste Systems, Inc. to Host Conference Call on Its Fourth Quarter 2023 Results',
#   'category': 'company_business_news'},
#  {'id': '65cecfecabb31841109ce710',
#   'title': 'Shashijit Infraprojects standalone net profit declines 50.00% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65cdb694abb31841109cdf9c',
#   'title': 'Shree Salasar Consolidated December 2023 Net Sales at Rs 2.03 crore, up 287.61% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c9fa54f4fc8477f2ed80e5',
#   'title': 'Kennametal Standalone December 2023 Net Sales at Rs 270.80 crore, down 1.46% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c8384df4fc8477f2ed73a0',
#   'title': 'Abhinav Capital Services standalone net profit rises 252.17% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65c6e77cf4fc8477f2ed716e',
#   'title': 'Petroperu Will Make All Payments to Bondholders, Minister Says',
#   'category': 'market_news'},
#  {'id': '65c2f28fc119ff6e57a4394d',
#   'title': 'A Mississippi poultry plant is being sued by a woman whose 16-year-old son died working there',
#   'category': 'non_financial'},
#  {'id': '65c6e6d5f4fc8477f2ed6986',
#   'title': 'Cremica Agro Foods standalone net profit rises 300.00% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65c08781c119ff6e57a3f009',
#   'title': 'Apeejay Surrendra Park Hotels IPO: Retail portion fully booked within hours of opening; check latest GMP, other details | Mint',
#   'category': 'market_news'},
#  {'id': '65c44494da99411d474772b1',
#   'title': 'Globe Life (GL) Reports Q4 Earnings: What Key Metrics Have to Say',
#   'category': 'market_news'},
#  {'id': '65cadbe2f4fc8477f2ed8a2b',
#   'title': 'KBRA Assigns Preliminary Ratings to Morgan Stanley Residential Mortgage Loan Trust 2024-INV1 (MSRM 2024-INV1)',
#   'category': 'market_news'},
#  {'id': '65ced04fabb31841109ceced',
#   'title': 'Inviting the AI-powered 5G Era, GIGABYTE will Present Next-Gen Servers for AI/HPC, Telecom, and Green Computing Solutions at MWC 2024',
#   'category': 'company_business_news'},
#  {'id': '65c44419da99411d47476c6e',
#   'title': 'Sleep Doctor partners with Airway Management to offer myTAP® Oral Appliance',
#   'category': 'company_business_news'},
#  {'id': '65cd7f00abb31841109cdc99',
#   'title': 'Bullish brokerage notes bolster PSU stocks higher on Wednesday',
#   'category': 'market_news'},
#  {'id': '65cc2cdb06df7536a8f6849b',
#   'title': "State-backed Oil India's third-quarter profit falls on lower crude prices",
#   'category': 'market_news'},
#  {'id': '65cf083babb31841109cf4d7',
#   'title': 'Global Apiculture Strategic Business Report 2024-2030: FlowT Hive Revolutionizes Honey Harvesting',
#   'category': 'company_business_news'},
#  {'id': '65c1d909c119ff6e57a433d7',
#   'title': "India's IOC sees growth in gasoline, diesel sales in FY2024/2025",
#   'category': 'market_news'},
#  {'id': '65c4448eda99411d47477261',
#   'title': 'Aspire at Sage Hill: Melcom Homes promotes sustainable luxury with new multi-family development',
#   'category': 'company_business_news'},
#  {'id': '65cecffbabb31841109ce88e',
#   'title': 'Space Incubatrics Technologies reports consolidated net profit of Rs 0.04 crore in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65cadbd4f4fc8477f2ed8969',
#   'title': 'Great Inflation Hedge Unwind Sees TIPS ETFs Lose $43 Billion',
#   'category': 'market_news'},
#  {'id': '65cd7e74abb31841109cd54c',
#   'title': 'NINtec Systems standalone net profit rises 182.64% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65cadbb4f4fc8477f2ed87c8',
#   'title': '2 Healthcare Stocks That Could Help Set You Up for Life',
#   'category': 'personal_finance'},
#  {'id': '65c1d474c119ff6e57a409c3',
#   'title': 'John Lewis denies blocking staff from joining union ahead of mass job cuts',
#   'category': 'company_business_news'},
#  {'id': '65cadba7f4fc8477f2ed8715',
#   'title': '\u200b\u200bStriking A Chord: Investors Tune Into The Lucrative Harmony Of Music Memorabilia',
#   'category': 'non_financial'},
#  {'id': '65cdef10abb31841109ce458',
#   'title': 'Best Income Stocks to Buy for February 15th',
#   'category': 'personal_finance'},
#  {'id': '65c1d6b8c119ff6e57a4274a',
#   'title': 'Why Atlassian Stock Got Hammered Today',
#   'category': 'market_news'},
#  {'id': '65c362dd17f2c04a90ee4ea3',
#   'title': 'Sino Biopharmaceutical to divest 67% stake in unit CP Qingdao for $253 mln',
#   'category': 'market_news'},
#  {'id': '65c21189c119ff6e57a4355e',
#   'title': 'Net Asset Value(s)',
#   'category': 'market_news'},
#  {'id': '65c8a8d0f4fc8477f2ed77fa',
#   'title': 'CG-VAK Software & Exports consolidated net profit declines 43.44% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65c9c210f4fc8477f2ed7f75',
#   'title': 'Sadbhav Engg Standalone December 2023 Net Sales at Rs 114.70 crore, down 45.36% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c595b961e5050757966b9a',
#   'title': 'RCI Hospitality: Fiscal Q1 Earnings Snapshot',
#   'category': 'market_news'},
#  {'id': '65c08797c119ff6e57a3f0a2',
#   'title': 'Dollar notches fresh highs as Fed cut bets recede',
#   'category': 'market_news'},
#  {'id': '65c989e2f4fc8477f2ed7a5c',
#   'title': "Nirma's open offer to buy more stake in Glenmark Life to start on Feb 15",
#   'category': 'market_news'},
#  {'id': '65c2f29fc119ff6e57a43a21',
#   'title': 'Restaurant Brands (QSR) Earnings Expected to Grow: Should You Buy?',
#   'category': 'market_news'},
#  {'id': '65c595e561e5050757966dc7',
#   'title': 'US Plan to Refill Oil Reserve Hits Snag as It Shuns Some Light Crudes',
#   'category': 'market_news'},
#  {'id': '65c595f061e5050757966e5b',
#   'title': 'Squarespace (SQSP) Stock Sinks As Market Gains: What You Should Know',
#   'category': 'market_news'},
#  {'id': '65cadbbbf4fc8477f2ed881c',
#   'title': 'Elon Musk Wanted To Sell Tesla To Apple, But CEO Tim Cook Does Not Recall Ever Speaking To Him',
#   'category': 'non_financial'},
#  {'id': '65c211e1c119ff6e57a436dc',
#   'title': "Zerodha AMC's LIQUIDCASE hits ₹150 crore AUM in 7 sessions: How is it different from other liquid ETFs?",
#   'category': 'personal_finance'},
#  {'id': '65c60606f4fc8477f2ed67f1',
#   'title': 'MAXIMA GRUPĖ receives SBTi validation for its greenhouse gas emissions reduction target',
#   'category': 'company_business_news'},
#  {'id': '65cd7eb0abb31841109cd88b',
#   'title': 'G2 Data & Solutions Power Revenue Outcomes for Sales Teams',
#   'category': 'company_business_news'}]

# %%
df = pd.DataFrame(k)

# %%
df_turbo = pd.DataFrame(k_turbo)

# %%
df_turbo.rename(columns = {'category': 'cat_turbo'})
# Out:
#                           id  \
# 0   65c32a9ac119ff6e57a4414e
# 1   65cc2d1e06df7536a8f68774
# 2   65c605c3f4fc8477f2ed657f
# 3   65cd7ed5abb31841109cda5e
# 4   65c9fa4cf4fc8477f2ed8093
# ..                       ...
# 75  65c595f061e5050757966e5b
# 76  65cadbbbf4fc8477f2ed881c
# 77  65c211e1c119ff6e57a436dc
# 78  65c60606f4fc8477f2ed67f1
# 79  65cd7eb0abb31841109cd88b
#
#                                                 title  \
# 0   Greaves Retail's multi-brand AutoEVMart partne...
# 1   Barclays VP sues for $290,000, alleging discri...
# 2   RBI mandates lenders to furnish Key Fact State...
# 3                         Breaking Stigmas About STEM
# 4   Uflex Standalone December 2023 Net Sales at Rs...
# ..                                                ...
# 75  Squarespace (SQSP) Stock Sinks As Market Gains...
# 76  Elon Musk Wanted To Sell Tesla To Apple, But C...
# 77  Zerodha AMC's LIQUIDCASE hits ₹150 crore AUM i...
# 78  MAXIMA GRUPĖ receives SBTi validation for its ...
# 79  G2 Data & Solutions Power Revenue Outcomes for...
#
#                    cat_turbo
# 0      company_business_news
# 1      company_business_news
# 2   economic_policies_trends
# 3              non_financial
# 4                market_news
# ..                       ...
# 75               market_news
# 76             non_financial
# 77          personal_finance
# 78     company_business_news
# 79     company_business_news
#
# [80 rows x 3 columns]

# %%
df_merged = pd.merge(df, df_turbo.rename(columns = {'category': 'cat_turbo'}), how = 'outer', on = ['id', 'title'])

# %%
df_merged.groupby('cat_turbo')['id'].count()
# Out:
# cat_turbo
# company_business_news       17
# economic_policies_trends     4
# market_news                 49
# non_financial                5
# personal_finance             5
# Name: id, dtype: int64

# %%
df_merged['different'] = df_merged['category'] != df_merged['cat_turbo']

# %%
df_merged[df_merged.different == True].to_dict('records')
# Out:
# [{'id': '65cc2d5106df7536a8f68a0e',
#   'title': 'Millions struggle with student loan repayments amid stubborn inflation',
#   'category': 'personal_finance',
#   'cat_turbo': 'economic_policies_trends',
#   'different': True},
#  {'id': '65cc2d0506df7536a8f6862e',
#   'title': 'The Fashion and Management Missteps That Left Express Clinging to Solvency',
#   'category': 'company_business_news',
#   'cat_turbo': 'market_news',
#   'different': True},
#  {'id': '65c6e744f4fc8477f2ed6e5e',
#   'title': 'How to Boost Your Portfolio with Top Oils-Energy Stocks Set to Beat Earnings',
#   'category': 'market_news',
#   'cat_turbo': 'personal_finance',
#   'different': True},
#  {'id': '65ced06fabb31841109cee87',
#   'title': 'ExxonMobil Obtains Exemption from Canadian Oil and Gas Reporting Obligations',
#   'category': 'economic_policies_trends',
#   'cat_turbo': 'market_news',
#   'different': True},
#  {'id': '65c1d759c119ff6e57a42f8c',
#   'title': 'AM Best Places Credit Ratings for Several Subsidiaries of The Cigna Group Under Review with Developing Implications',
#   'category': 'company_business_news',
#   'cat_turbo': 'market_news',
#   'different': True},
#  {'id': '65c6e77cf4fc8477f2ed716e',
#   'title': 'Petroperu Will Make All Payments to Bondholders, Minister Says',
#   'category': 'economic_policies_trends',
#   'cat_turbo': 'market_news',
#   'different': True},
#  {'id': '65c2f28fc119ff6e57a4394d',
#   'title': 'A Mississippi poultry plant is being sued by a woman whose 16-year-old son died working there',
#   'category': 'company_business_news',
#   'cat_turbo': 'non_financial',
#   'different': True},
#  {'id': '65cf083babb31841109cf4d7',
#   'title': 'Global Apiculture Strategic Business Report 2024-2030: FlowT Hive Revolutionizes Honey Harvesting',
#   'category': 'market_news',
#   'cat_turbo': 'company_business_news',
#   'different': True},
#  {'id': '65c1d909c119ff6e57a433d7',
#   'title': "India's IOC sees growth in gasoline, diesel sales in FY2024/2025",
#   'category': 'economic_policies_trends',
#   'cat_turbo': 'market_news',
#   'different': True},
#  {'id': '65cadbd4f4fc8477f2ed8969',
#   'title': 'Great Inflation Hedge Unwind Sees TIPS ETFs Lose $43 Billion',
#   'category': 'economic_policies_trends',
#   'cat_turbo': 'market_news',
#   'different': True},
#  {'id': '65cadbb4f4fc8477f2ed87c8',
#   'title': '2 Healthcare Stocks That Could Help Set You Up for Life',
#   'category': 'market_news',
#   'cat_turbo': 'personal_finance',
#   'different': True},
#  {'id': '65cadba7f4fc8477f2ed8715',
#   'title': '\u200b\u200bStriking A Chord: Investors Tune Into The Lucrative Harmony Of Music Memorabilia',
#   'category': 'market_news',
#   'cat_turbo': 'non_financial',
#   'different': True},
#  {'id': '65cdef10abb31841109ce458',
#   'title': 'Best Income Stocks to Buy for February 15th',
#   'category': 'market_news',
#   'cat_turbo': 'personal_finance',
#   'different': True},
#  {'id': '65c362dd17f2c04a90ee4ea3',
#   'title': 'Sino Biopharmaceutical to divest 67% stake in unit CP Qingdao for $253 mln',
#   'category': nan,
#   'cat_turbo': 'market_news',
#   'different': True},
#  {'id': '65c21189c119ff6e57a4355e',
#   'title': 'Net Asset Value(s)',
#   'category': nan,
#   'cat_turbo': 'market_news',
#   'different': True},
#  {'id': '65c8a8d0f4fc8477f2ed77fa',
#   'title': 'CG-VAK Software & Exports consolidated net profit declines 43.44% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': nan,
#   'cat_turbo': 'market_news',
#   'different': True},
#  {'id': '65c9c210f4fc8477f2ed7f75',
#   'title': 'Sadbhav Engg Standalone December 2023 Net Sales at Rs 114.70 crore, down 45.36% Y-o-Y',
#   'category': nan,
#   'cat_turbo': 'market_news',
#   'different': True},
#  {'id': '65c595b961e5050757966b9a',
#   'title': 'RCI Hospitality: Fiscal Q1 Earnings Snapshot',
#   'category': nan,
#   'cat_turbo': 'market_news',
#   'different': True},
#  {'id': '65c08797c119ff6e57a3f0a2',
#   'title': 'Dollar notches fresh highs as Fed cut bets recede',
#   'category': nan,
#   'cat_turbo': 'market_news',
#   'different': True},
#  {'id': '65c989e2f4fc8477f2ed7a5c',
#   'title': "Nirma's open offer to buy more stake in Glenmark Life to start on Feb 15",
#   'category': nan,
#   'cat_turbo': 'market_news',
#   'different': True},
#  {'id': '65c2f29fc119ff6e57a43a21',
#   'title': 'Restaurant Brands (QSR) Earnings Expected to Grow: Should You Buy?',
#   'category': nan,
#   'cat_turbo': 'market_news',
#   'different': True},
#  {'id': '65c595e561e5050757966dc7',
#   'title': 'US Plan to Refill Oil Reserve Hits Snag as It Shuns Some Light Crudes',
#   'category': nan,
#   'cat_turbo': 'market_news',
#   'different': True},
#  {'id': '65c595f061e5050757966e5b',
#   'title': 'Squarespace (SQSP) Stock Sinks As Market Gains: What You Should Know',
#   'category': nan,
#   'cat_turbo': 'market_news',
#   'different': True},
#  {'id': '65cadbbbf4fc8477f2ed881c',
#   'title': 'Elon Musk Wanted To Sell Tesla To Apple, But CEO Tim Cook Does Not Recall Ever Speaking To Him',
#   'category': nan,
#   'cat_turbo': 'non_financial',
#   'different': True},
#  {'id': '65c211e1c119ff6e57a436dc',
#   'title': "Zerodha AMC's LIQUIDCASE hits ₹150 crore AUM in 7 sessions: How is it different from other liquid ETFs?",
#   'category': nan,
#   'cat_turbo': 'personal_finance',
#   'different': True},
#  {'id': '65c60606f4fc8477f2ed67f1',
#   'title': 'MAXIMA GRUPĖ receives SBTi validation for its greenhouse gas emissions reduction target',
#   'category': nan,
#   'cat_turbo': 'company_business_news',
#   'different': True},
#  {'id': '65cd7eb0abb31841109cd88b',
#   'title': 'G2 Data & Solutions Power Revenue Outcomes for Sales Teams',
#   'category': nan,
#   'cat_turbo': 'company_business_news',
#   'different': True}]

# %% [markdown]
# - Observing that GPT4 is giving better responses. Hence going with it

# %%
def fetch_title_classes(chunk_str, chunk_index):
    r_cur = client.chat.completions.create(model = 'gpt-4', messages = [{'role': 'system', 'content': prompt}, {'role': 'user', 'content': chunk_str}])
    res = r_cur.choices[0].message.content
    try:
        parsed_res = json.loads(res)
    except:
        parsed_res = None
    completion_tokens = r_cur.usage.completion_tokens
    prompt_tokens = r_cur.usage.prompt_tokens
    return chunk_index, res, parsed_res, completion_tokens, prompt_tokens

# %%
a,b,c,d,e = fetch_title_classes(chunk_str=chunk_string,chunk_index=99)

# %%
e
# Out:
# 2641

# %%
shortlisted_articles = list(np.random.choice(all_articles, 5000))

# %%
chunk_size = 50
num_chunks = int(len(shortlisted_articles)/chunk_size)
chunk_str_dict = {}
for i in range(num_chunks):
    chunk = shortlisted_articles[chunk_size*i:chunk_size*(i+1)]
    chunk_json_list = [{'id': x['article_id'], 'title': x['title']} for x in chunk]
    chunk_string = json.dumps(chunk_json_list)
    chunk_str_dict[i] = chunk_string

# %%
title_class_results = {}

# %%
import time

# %%
s = time.time()
with ThreadPoolExecutor(max_workers=15) as executor:
    futures = [executor.submit(fetch_title_classes, chunkstr, ind) for ind, chunkstr in chunk_str_dict.items()]
    for future in as_completed(futures):
        index, response, parsed_response, num_completion_tokens, num_prompt_tokens = future.result()
        title_class_results[index] = {'res': response, 'parsed_res': parsed_response, 'com_tokens': num_completion_tokens, 'prompt_tokens': num_prompt_tokens}
        print(f'done with index {index} in {time.time() - s} seconds')
    print(f'done in {time.time() - s} seconds')
# Out:
# done with index 4 in 76.01502013206482 seconds
# done with index 3 in 76.37697315216064 seconds
# done with index 5 in 80.05090093612671 seconds
# done with index 1 in 80.75662994384766 seconds
# done with index 7 in 94.20979404449463 seconds
# done with index 2 in 94.9927008152008 seconds
# done with index 14 in 97.59425711631775 seconds
# done with index 13 in 97.93184208869934 seconds
# done with index 12 in 101.55906510353088 seconds
# done with index 11 in 101.64088296890259 seconds
# done with index 9 in 110.98307204246521 seconds
# done with index 0 in 125.1488950252533 seconds
# done with index 6 in 131.43558812141418 seconds
# done with index 8 in 134.0529909133911 seconds
# done with index 15 in 160.98313283920288 seconds
# done with index 18 in 162.55887413024902 seconds
# done with index 19 in 180.1961431503296 seconds
# done with index 20 in 180.27190494537354 seconds
# done with index 25 in 194.939532995224 seconds
# done with index 10 in 197.22592616081238 seconds
# done with index 17 in 202.9684669971466 seconds
# done with index 16 in 205.3635058403015 seconds
# done with index 27 in 219.08278799057007 seconds
# done with index 22 in 226.6720371246338 seconds
# done with index 24 in 235.3023111820221 seconds
# done with index 23 in 242.22001004219055 seconds
# done with index 26 in 250.45665407180786 seconds
# done with index 21 in 250.97988986968994 seconds
# done with index 28 in 251.5666859149933 seconds
# done with index 29 in 271.4250280857086 seconds
# done with index 33 in 273.15624022483826 seconds
# done with index 30 in 275.21451592445374 seconds
# done with index 31 in 276.72407698631287 seconds
# done with index 35 in 280.33798599243164 seconds
# done with index 34 in 308.17391419410706 seconds
# done with index 38 in 323.60693287849426 seconds
# done with index 39 in 332.3544189929962 seconds
# done with index 32 in 333.2859170436859 seconds
# done with index 37 in 334.51956701278687 seconds
# done with index 40 in 338.3078022003174 seconds
# done with index 42 in 355.3080129623413 seconds
# done with index 46 in 358.69447088241577 seconds
# done with index 41 in 367.58247900009155 seconds
# done with index 45 in 374.0483310222626 seconds
# done with index 43 in 375.23501896858215 seconds
# done with index 48 in 380.1440079212189 seconds
# done with index 36 in 396.72651386260986 seconds
# done with index 44 in 399.38054513931274 seconds
# done with index 47 in 406.9933409690857 seconds
# done with index 49 in 411.55042719841003 seconds
# done with index 54 in 423.59773993492126 seconds
# done with index 51 in 436.1321499347687 seconds
# done with index 52 in 449.8329060077667 seconds
# done with index 53 in 451.41756415367126 seconds
# done with index 55 in 467.72864413261414 seconds
# done with index 50 in 473.63338589668274 seconds
# done with index 56 in 482.5558042526245 seconds
# done with index 57 in 485.1299059391022 seconds
# done with index 59 in 485.80960512161255 seconds
# done with index 63 in 491.2732012271881 seconds
# done with index 60 in 494.40051198005676 seconds
# done with index 58 in 496.6491940021515 seconds
# done with index 61 in 509.6808271408081 seconds
# done with index 65 in 510.1845829486847 seconds
# done with index 62 in 517.9850480556488 seconds
# done with index 66 in 528.5891370773315 seconds
# done with index 64 in 533.0123782157898 seconds
# done with index 68 in 535.8027000427246 seconds
# done with index 67 in 557.518620967865 seconds
# done with index 75 in 557.8393211364746 seconds
# done with index 69 in 560.5509119033813 seconds
# done with index 70 in 567.5660910606384 seconds
# done with index 72 in 579.9695019721985 seconds
# done with index 73 in 581.2318699359894 seconds
# done with index 74 in 594.2713429927826 seconds
# done with index 71 in 604.4852850437164 seconds
# done with index 77 in 615.4942450523376 seconds
# done with index 80 in 623.789144039154 seconds
# done with index 76 in 625.5183670520782 seconds
# done with index 81 in 636.6092669963837 seconds
# done with index 79 in 636.6173439025879 seconds
# done with index 85 in 636.7214729785919 seconds
# done with index 78 in 638.3883059024811 seconds
# done with index 82 in 652.1984040737152 seconds
# done with index 83 in 672.848906993866 seconds
# done with index 89 in 673.1655230522156 seconds
# done with index 86 in 680.8085188865662 seconds
# done with index 84 in 684.2516479492188 seconds
# done with index 88 in 689.9399449825287 seconds
# done with index 91 in 692.3192901611328 seconds
# done with index 87 in 699.5753259658813 seconds
# done with index 93 in 706.2032999992371 seconds
# done with index 92 in 713.1167860031128 seconds
# done with index 90 in 716.1606299877167 seconds
# done with index 96 in 724.6821820735931 seconds
# done with index 95 in 755.6117260456085 seconds
# done with index 99 in 763.2412281036377 seconds
# done with index 97 in 765.9702498912811 seconds
# done with index 94 in 766.0296649932861 seconds
# done with index 98 in 773.4876930713654 seconds
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[144], line 8
#       6     title_class_results[index] = {'res': response, 'parsed_res': parsed_response, 'com_tokens': num_completion_tokens, 'prompt_tokens': num_prompt_tokens}
#       7     print(f'done with index {index} in {time.time() - s} seconds')
# ----> 8 print(f'done in {time.time() - start_time} seconds')
#
# NameError: name 'start_time' is not defined

# %%
len(title_class_results)
# Out:
# 100

# %%
path = '/Users/username/Downloads/swift_thinking/emails'

# %%
shortlisted_parsed_results = []

# %%
for ind, results in title_class_results.items():
    if not results['parsed_res']:
        print(f'not valid json for {ind}')
    else:
        shortlisted_parsed_results.extend(results['parsed_res'])

# %%
len(shortlisted_parsed_results)
# Out:
# 4985

# %%
shortlisted_parsed_results
# Out:
# [{'id': '65c32ac0c119ff6e57a441f5',
#   'title': 'Nykredit today announces the Annual Reports for 2023 - Nykredit Realkredit A/S',
#   'category': 'company_business_news'},
#  {'id': '65c1d469c119ff6e57a40934',
#   'title': 'Crown Realty Partners Expands Portfolio With Acquisition of Atrium Building in Mississauga',
#   'category': 'company_business_news'},
#  {'id': '65cd7eb7abb31841109cd8e5',
#   'title': 'Cennox announces a nationwide service contract with FLO, to support reliability in EV charging infrastructure across the US',
#   'category': 'company_business_news'},
#  {'id': '65c989cbf4fc8477f2ed78f6',
#   'title': 'NYKAA Share Price Live blog for 12 Feb 2024 | Mint',
#   'category': 'market_news'},
#  {'id': '65c4b45e61e5050757966385',
#   'title': 'India ranks fourth in the world in Renewable Energy Installed Capacity says PM',
#   'category': 'economic_policies_trends'},
#  {'id': '65cadb92f4fc8477f2ed860d',
#   'title': 'Roc Nation Lands A Multi-Year Deal With Versace That Will Provide Event Sponsorships And Scholarships For The Next Generation',
#   'category': 'company_business_news'},
#  {'id': '65c1d475c119ff6e57a409d9',
#   'title': 'PRESS DIGEST-British Business - Feb 6',
#   'category': 'company_business_news'},
#  {'id': '65cadbccf4fc8477f2ed8905',
#   'title': 'InventHelp Inventor Develops Coiled Plumbing Device (LAX-1589)',
#   'category': 'company_business_news'},
#  {'id': '65c1d5a3c119ff6e57a4192b',
#   'title': 'Cigna Corporation (NYSE:CI) Q4 2023 Earnings Call Transcript',
#   'category': 'market_news'},
#  {'id': '65c21188c119ff6e57a43550',
#   'title': "Tineco's Valentine's Day Ideas for the Household",
#   'category': 'company_business_news'},
#  {'id': '65cd7e8babb31841109cd6ac',
#   'title': 'New Gold (NGD) Q4 2023 Earnings Call Transcript',
#   'category': 'market_news'},
#  {'id': '65cd7e9fabb31841109cd7b2',
#   'title': 'Revised Quarterly GDM Prospect for Q1 2024',
#   'category': 'market_news'},
#  {'id': '65cd7e8fabb31841109cd6dc',
#   'title': 'NETSTREIT (NTST) Reports Q4 Earnings: What Key Metrics Have to Say',
#   'category': 'market_news'},
#  {'id': '65ced051abb31841109cecfc',
#   'title': 'Pembina Pipeline (PBA) Reports Next Week: Wall Street Expects Earnings Growth',
#   'category': 'market_news'},
#  {'id': '65c443e7da99411d47476b08',
#   'title': 'Siemens investors call for further unbundling of the group',
#   'category': 'company_business_news'},
#  {'id': '65c44423da99411d47476cf3',
#   'title': 'Asian shares track Wall Street higher; China deflation risks persist',
#   'category': 'market_news'},
#  {'id': '65cd7ee2abb31841109cdb19',
#   'title': 'Avangrid (AGR) Reports Next Week: Wall Street Expects Earnings Growth',
#   'category': 'market_news'},
#  {'id': '65cadbedf4fc8477f2ed8ad1',
#   'title': 'Adhesion Promoter Market Set to Reach $5.3 Billion by 2028, Driven by Demand in Automotive, Construction, and Electronics Sectors',
#   'category': 'market_news'},
#  {'id': '65cd7efdabb31841109cdc72',
#   'title': 'Nine Workers Missing After Landslide Strikes Gold Mine in Turkey',
#   'category': 'economic_policies_trends'},
#  {'id': '65c1a0e5c119ff6e57a3f359',
#   'title': 'Where to Buy Spot Bitcoin ETFs in 2024',
#   'category': 'personal_finance'},
#  {'id': '65ced081abb31841109cef7a',
#   'title': 'InterDigital (IDCC) Q4 Earnings and Revenues Top Estimates',
#   'category': 'market_news'},
#  {'id': '65c6e72ff4fc8477f2ed6d45',
#   'title': 'How to choose a business credit card',
#   'category': 'personal_finance'},
#  {'id': '65c4449fda99411d4747733d',
#   'title': 'Analysts Estimate Nu Skin Enterprises (NUS) to Report a Decline in Earnings: What to Look Out for',
#   'category': 'market_news'},
#  {'id': '65c4446eda99411d474770ba',
#   'title': '10x Genomics Expands Leadership in Single Cell Analysis with Launch of GEM-X Technology',
#   'category': 'company_business_news'},
#  {'id': '65c6e6dcf4fc8477f2ed6a31',
#   'title': 'WTO MC13: India to oppose any negotiation mandate on non-trade issues',
#   'category': 'economic_policies_trends'},
#  {'id': '65c60610f4fc8477f2ed686b',
#   'title': 'German inflation eases to 3.1% in January',
#   'category': 'economic_policies_trends'},
#  {'id': '65c1d7a6c119ff6e57a4337f',
#   'title': 'Returns On Capital At RCI Hospitality Holdings (NASDAQ:RICK) Have Hit The Brakes',
#   'category': 'market_news'},
#  {'id': '65cf0842abb31841109cf510',
#   'title': 'AMLO Tightens Grip on Mexico Energy as Iberdrola Deal Gets Nod',
#   'category': 'economic_policies_trends'},
#  {'id': '65bb79d5f3aa2a77a58bfee7',
#   'title': 'Budget pegs RBI, PSU banks dividend in FY25 at Rs 1.02 lakh crore',
#   'category': 'economic_policies_trends'},
#  {'id': '65c1d6e9c119ff6e57a429c3',
#   'title': 'Bankers rebel against return of big bonuses',
#   'category': 'economic_policies_trends'},
#  {'id': '65cc2d1406df7536a8f686e8',
#   'title': 'MORNING BID ASIA-Bracing for US inflation aftershock',
#   'category': 'market_news'},
#  {'id': '65cd7e8aabb31841109cd696',
#   'title': "Here's Why Micron (MU) Gained But Lagged the Market Today",
#   'category': 'market_news'},
#  {'id': '65cd7edaabb31841109cdaa1',
#   'title': 'Proteomics Market: Unveiling the Secrets of Proteins for Precision Medicine with market Size & Share to exceed US$ 380.7 Billion by 2034, at CAGR of 29.20% – By PMI',
#   'category': 'market_news'},
#  {'id': '65c83857f4fc8477f2ed7480',
#   'title': "Ads take Blinkit past Zomato's food delivery business growth in Q3",
#   'category': 'company_business_news'},
#  {'id': '65bc9315f3aa2a77a58c0285',
#   'title': 'Dr Lal PathLab Consolidated December 2023 Net Sales at Rs 538.90 crore, up 10.11% Y-o-Y',
#   'category': 'company_business_news'},
#  {'id': '65cdef03abb31841109ce3be',
#   'title': 'CINEO LIGHTING UNVEILS NEW REFLEX R10 AT 2024 BSC EXPO',
#   'category': 'company_business_news'},
#  {'id': '65cecffcabb31841109ce8a2',
#   'title': 'KFC Thailand and the Equal Education FundLaunch Successful Bucket Search Orientations To Tackle Educational Inequality',
#   'category': 'company_business_news'},
#  {'id': '65c1a0e3c119ff6e57a3f33d',
#   'title': 'Arihant Capital Markets consolidated net profit rises 173.60% in the December 2023 quarter',
#   'category': 'company_business_news'},
#  {'id': '65cb13c3f4fc8477f2ed8fa2',
#   'title': 'Decisions adopted in the Extraordinary General Meeting of Shareholders of LITGRID AB',
#   'category': 'company_business_news'},
#  {'id': '65cc2d1306df7536a8f686e2',
#   'title': 'HighRadius Hosts 10th Annual Radiance, the Office of the CFO UNconference on Feb 13-14',
#   'category': 'company_business_news'},
#  {'id': '65cb4bc98c9dc047f1e03fe8',
#   'title': "PhysicsWallah Cofounder Alakh Pandey's Remuneration More Than Halves To INR 4.6 Cr In FY23",
#   'category': 'personal_finance'},
#  {'id': '65ced04eabb31841109cecda',
#   'title': 'Health Coalition Exposes Significantly Higher Costs & Irregularities in Kingston Hospital Cataract Surgery Privatization: New Report',
#   'category': 'company_business_news'},
#  {'id': '65c4b48161e5050757966434',
#   'title': 'DIAMOND OFFSHORE ANNOUNCES NEW FLOATER COMMITMENTS',
#   'category': 'company_business_news'},
#  {'id': '65c2f288c119ff6e57a438f9',
#   'title': 'Zscaler (ZS) Outpaces Stock Market Gains: What You Should Know',
#   'category': 'market_news'},
#  {'id': '65c443ddda99411d47476a74',
#   'title': 'Petrobras in talks for projects with Gulf, Indian, Chinese firms, CEO says',
#   'category': 'company_business_news'},
#  {'id': '65cd7f06abb31841109cdce3',
#   'title': 'Williams Companies, Inc. (The) (WMB) Reports Q4 Earnings: What Key Metrics Have to Say',
#   'category': 'market_news'},
#  {'id': '65c1d50bc119ff6e57a4116f',
#   'title': 'N.C. Pesticide Board announces case settlements',
#   'category': 'company_business_news'},
#  {'id': '65c21189c119ff6e57a43553',
#   'title': "Fibra Uno Administracion SA de CV's Dividend Analysis",
#   'category': 'company_business_news'},
#  {'id': '65cc6543abb31841109cce82',
#   'title': 'Norsk Hydro: Key information related to proposed cash dividend',
#   'category': 'company_business_news'},
#  {'id': '65cc2ce206df7536a8f68509',
#   'title': 'Boeing, pressured over 737 MAX 9 blowout, says January deliveries shrank 29%',
#   'category': 'company_business_news'},
#  {'id': '65cc2d1f06df7536a8f68784',
#   'title': 'Horizon Technology Finance to Announce Fourth Quarter 2023 Financial Results',
#   'category': 'company_business_news'},
#  {'id': '65c1d797c119ff6e57a432c3',
#   'title': 'Crop Production Software Market Projected USD 2.22 Billion Growth between 2024 and 2028: Market to focus on Precision Farming and Data Management - Technavio',
#   'category': 'market_news'},
#  {'id': '65cc2d1006df7536a8f686bd',
#   'title': 'UPDATE 2-America Movil Q4 net profit jumps, revenue dips on strong peso',
#   'category': 'market_news'},
#  {'id': '65cdeefeabb31841109ce374',
#   'title': "Analysis-Russia's reserves dwindle, but fiscal safety net could last years",
#   'category': 'economic_policies_trends'},
#  {'id': '65ced04cabb31841109cecbd',
#   'title': 'Grand Touring Automobiles celebrates 50 years of excellence at Canadian International AutoShow',
#   'category': 'company_business_news'},
#  {'id': '65cadb55f4fc8477f2ed838a',
#   'title': "India's January CPI inflation eases to 5.10%, core inflation drops to 3.6%",
#   'category': 'economic_policies_trends'},
#  {'id': '65befdcff3aa2a77a58c0713',
#   'title': "Shareholders Prosus, others call for ouster of Byju's founders in new salvo",
#   'category': 'company_business_news'},
#  {'id': '65cecff0abb31841109ce770',
#   'title': 'PTC Industries consolidated net profit rises 32.68% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65c5961161e505075796700f',
#   'title': 'Form 8.3 - [CITY PUB GROUP PLC - 07 02 2024] - (CGAML)',
#   'category': 'company_business_news'},
#  {'id': '65c2f2fbc119ff6e57a43eeb',
#   'title': 'Are Consumer Staples Stocks Lagging Clorox (CLX) This Year?',
#   'category': 'market_news'},
#  {'id': '65cb13c3f4fc8477f2ed8f9e',
#   'title': 'Uniform Advantage® Champions Black Excellence in Medicine with Open Dialogue Series for Black History Month',
#   'category': 'non_financial'},
#  {'id': '65c8384af4fc8477f2ed736f',
#   'title': 'Mahalaxmi Rubtech consolidated net profit rises 7.11% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65c2f311c119ff6e57a44012',
#   'title': "Akamai Technologies (AKAM) Earnings Expected to Grow: What to Know Ahead of Next Week's Release",
#   'category': 'market_news'},
#  {'id': '65ced009abb31841109ce962',
#   'title': 'Fairview Microwave Unveils Phase Shifters and Continuously Variable Attenuators',
#   'category': 'company_business_news'},
#  {'id': '65c605f3f4fc8477f2ed6760',
#   'title': 'Garware Marine Industries standalone net profit declines 50.00% in the December 2023 quarter',
#   'category': 'company_business_news'},
#  {'id': '65c989e2f4fc8477f2ed7a62',
#   'title': 'KIFS Financial Services standalone net profit rises 64.04% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65cdef16abb31841109ce4a8',
#   'title': 'Shareholders in Broadway Financial (NASDAQ:BYFC) are in the red if they invested three years ago',
#   'category': 'market_news'},
#  {'id': '65c8a8f5f4fc8477f2ed785e',
#   'title': 'This musicMagpie Insider Increased Their Holding By 451% Last Year',
#   'category': 'market_news'},
#  {'id': '65c6e72df4fc8477f2ed6d28',
#   'title': 'Why Spire Global Stock Just Rocketed to the Moon',
#   'category': 'market_news'},
#  {'id': '65c9c209f4fc8477f2ed7f27',
#   'title': 'Entero Healthcare Solutions IPO: From financials to key risks, here are 10 key things to know from RHP | Mint',
#   'category': 'market_news'},
#  {'id': '65cc2cde06df7536a8f684cc',
#   'title': 'Sbi Share Price Live blog for 14 Feb 2024 | Mint',
#   'category': 'market_news'},
#  {'id': '65c21192c119ff6e57a435c2',
#   'title': "RPT-India to remain on alert for 'hot money' after bond index inclusion - official",
#   'category': 'economic_policies_trends'},
#  {'id': '65cc2d4106df7536a8f68929',
#   'title': "AMC Networks Inc. Earnings Missed Analyst Estimates: Here's What Analysts Are Forecasting Now",
#   'category': 'market_news'},
#  {'id': '65c47c21da99411d47477565',
#   'title': "NCLT issues notice on Zee's plea seeking directions for Sony merger",
#   'category': 'company_business_news'},
#  {'id': '65c595bd61e5050757966bd4',
#   'title': 'Instacart and Hy-Vee Partner to Meet Growing Demand for Same-Day Delivery',
#   'category': 'company_business_news'},
#  {'id': '65cadb4af4fc8477f2ed8310',
#   'title': 'Suzlon Share Price Live blog for 13 Feb 2024 | Mint',
#   'category': 'market_news'},
#  {'id': '65cc2d1c06df7536a8f68756',
#   'title': 'Dungeons & Dragons Celebrates 50th Anniversary in 2024 with More than 50 Million Fans',
#   'category': 'non_financial'},
#  {'id': '65cc651dabb31841109ccd6a',
#   'title': 'Binny Mills Standalone December 2023 Net Sales at Rs 1.81 crore, down 9.45% Y-o-Y',
#   'category': 'company_business_news'},
#  {'id': '65cd7ef7abb31841109cdc23',
#   'title': 'Compared to Estimates, Pegasystems (PEGA) Q4 Earnings: A Look at Key Metrics',
#   'category': 'market_news'},
#  {'id': '65c47c5ada99411d47477603',
#   'title': 'Estimating The Fair Value Of Yenher Holdings Berhad (KLSE:YENHER)',
#   'category': 'market_news'},
#  {'id': '65cb4c068c9dc047f1e04190',
#   'title': 'UK’s Stronger-Than-Expected Wage Growth Bolsters BOE Caution',
#   'category': 'economic_policies_trends'},
#  {'id': '65cd7eb3abb31841109cd8b5',
#   'title': 'Ball Corporation Announces Cash Tender Offers for Certain Outstanding Debt Securities',
#   'category': 'company_business_news'},
#  {'id': '65c2f24fc119ff6e57a4373f',
#   'title': 'REC Share Price Live blog for 07 Feb 2024 | Mint',
#   'category': 'market_news'},
#  {'id': '65cc9d96abb31841109cd231',
#   'title': "Zambia's central bank increases lending rate by 150 basis points",
#   'category': 'economic_policies_trends'},
#  {'id': '65c5957b61e5050757966884',
#   'title': 'Coinbase Global, Inc. (COIN) Expected to Beat Earnings Estimates: What to Know Ahead of Q4 Release',
#   'category': 'market_news'},
#  {'id': '65cadbf4f4fc8477f2ed8b30',
#   'title': 'Patterson Cos. (PDCO) Rises As Market Takes a Dip: Key Facts',
#   'category': 'market_news'},
#  {'id': '65c1d417c119ff6e57a4050f',
#   'title': 'Stock Bull Run Powers Ahead as US Economy Roars: Markets Wrap',
#   'category': 'market_news'},
#  {'id': '65cadb87f4fc8477f2ed857d',
#   'title': 'Russian court orders arrest in absentia of Meta spokesperson',
#   'category': 'company_business_news'},
#  {'id': '65bccbe0f3aa2a77a58c0383',
#   'title': 'Adani Ports among top Nifty 50 gainers, analysts see up to 12% upside in stock after Q3 results',
#   'category': 'market_news'},
#  {'id': '65cd7e5babb31841109cd331',
#   'title': 'Future data centres may have built-in nuclear reactors',
#   'category': 'economic_policies_trends'},
#  {'id': '65c2f25ec119ff6e57a43820',
#   'title': 'Brookfield-backed India Infra InvIT to raise Rs 6,452 crore via debentures',
#   'category': 'economic_policies_trends'},
#  {'id': '65bdac41f3aa2a77a58c03b1',
#   'title': 'China gloom spurs record $2 billion rush into foreign stock ETFs | Mint',
#   'category': 'economic_policies_trends'},
#  {'id': '65c21195c119ff6e57a435eb',
#   'title': 'OpenAI-backed healthcare AI startup raises $70 million Series B',
#   'category': 'company_business_news'},
#  {'id': '65cadbedf4fc8477f2ed8acd',
#   'title': 'Union Home Mortgage Foundation announces fourth quarter grant recipients',
#   'category': 'personal_finance'},
#  {'id': '65c4b48661e5050757966463',
#   'title': 'Amkor Technology, Inc. (NASDAQ:AMKR) Analysts Are Pretty Bullish On The Stock After Recent Results',
#   'category': 'market_news'},
#  {'id': '65cc2d3906df7536a8f688be',
#   'title': 'Guardian Names Steve Rullo as Chief Digital and Technology Officer',
#   'category': 'company_business_news'},
#  {'id': '65ced092abb31841109cf05b',
#   'title': 'Mortgage Rates Rise',
#   'category': 'personal_finance'},
#  {'id': '65c8a8fbf4fc8477f2ed7892',
#   'title': 'Joby to Launch Air Taxi Service in UAE',
#   'category': 'company_business_news'},
#  {'id': '65c1d463c119ff6e57a408e9',
#   'title': 'Congress hasn’t been able to make social media safer. Here’s why',
#   'category': 'non_financial'},
#  {'id': '65c0bfd2c119ff6e57a3f166',
#   'title': 'Indigo Q3 PAT zooms 111% YoY to Rs 2,998 cr',
#   'category': 'company_business_news'},
#  {'id': '65c6e744f4fc8477f2ed6e68',
#   'title': 'Curis, Inc. (NASDAQ:CRIS) Q4 2023 Earnings Call Transcript',
#   'category': 'market_news'},
#  {'id': '65c44423da99411d47476cf3',
#   'title': 'Asian shares track Wall Street higher; China deflation risks persist',
#   'category': 'market_news'},
#  {'id': '65c1d4d8c119ff6e57a40ed8',
#   'title': 'Private equity firms own 23% of The Honest Company, Inc. (NASDAQ:HNST) shares but retail investors control 41% of the company',
#   'category': 'company_business_news'},
#  {'id': '65c1d77ac119ff6e57a4313d',
#   'title': 'Clearfield Reports Fiscal First Quarter 2024 Results',
#   'category': 'company_business_news'},
#  {'id': '65c47c1cda99411d4747750a',
#   'title': 'Electronics Mar Standalone December 2023 Net Sales at Rs 1,788.71 crore, up 20.72% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c9fa46f4fc8477f2ed807a',
#   'title': 'Mutual Funds vs bank deposits: A strategic shift in investment trend that you must know | Mint',
#   'category': 'personal_finance'},
#  {'id': '65c2114fc119ff6e57a434b6',
#   'title': 'Paytm’s best option would be a representation to RBI, say legal experts',
#   'category': 'economic_policies_trends'},
#  {'id': '65c8a8fdf4fc8477f2ed78a1',
#   'title': 'My 3 Monster AI Growth Stocks to Buy Hand Over Fist in the New Bull Market',
#   'category': 'market_news'},
#  {'id': '65cecfefabb31841109ce75f',
#   'title': 'Jattashankar Industries standalone net profit rises 1800.00% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65c21155c119ff6e57a43502',
#   'title': 'Australian interest rate changes since 1990',
#   'category': 'economic_policies_trends'},
#  {'id': '65c1d789c119ff6e57a43201',
#   'title': "Why Macy's (M) Dipped More Than Broader Market Today",
#   'category': 'market_news'},
#  {'id': '65cadc01f4fc8477f2ed8bd4',
#   'title': 'HSS Research Evaluates Whether AI Chatbots Provide Reliable Medical Information',
#   'category': 'company_business_news'},
#  {'id': '65c595a861e5050757966abb',
#   'title': 'Falvey Insurance Group Selects Domo to Create Actionable Data Experiences',
#   'category': 'company_business_news'},
#  {'id': '65cadbc2f4fc8477f2ed887b',
#   'title': 'High Wire Networks Named to CRN MSP 500 and Elite 150 Listings of Nation’s Top IT Managed Service Providers',
#   'category': 'company_business_news'},
#  {'id': '65cdeee1abb31841109ce233',
#   'title': 'Oil India Share price rises 12%; scale 52 week highs on strong volume outlook | Mint',
#   'category': 'market_news'},
#  {'id': '65cd7ef7abb31841109cdc25',
#   'title': 'Hempshire Group Announces Management Changes',
#   'category': 'company_business_news'},
#  {'id': '65c1d3c9c119ff6e57a40126',
#   'title': 'OCB Berhad (KLSE:OCB) Is Doing The Right Things To Multiply Its Share Price',
#   'category': 'market_news'},
#  {'id': '65cadb51f4fc8477f2ed8349',
#   'title': 'Buy or sell: Ruchit Jain of 5paisa recommends buying United Spirits and Apollo Hospitals stock this week | Mint',
#   'category': 'market_news'},
#  {'id': '65bb095bf3aa2a77a58bf96a',
#   'title': 'Bajaj Holdings & Investment Share Price Live blog for 01 Feb 2024 | Mint',
#   'category': 'market_news'},
#  {'id': '65ced094abb31841109cf06d',
#   'title': 'Crystal Lagoons Expands PAL™ Projects to Rome, Milan, Toulouse and Seville',
#   'category': 'company_business_news'},
#  {'id': '65c3630217f2c04a90ee4f84',
#   'title': 'Immunogen Inc SVP & CHIEF BUSINESS OFFICER Stacy Coen Sells 4,583 Shares',
#   'category': 'company_business_news'},
#  {'id': '65c98a05f4fc8477f2ed7b52',
#   'title': 'Why the 1960s can help us understand our confusing economic mood',
#   'category': 'economic_policies_trends'},
#  {'id': '65cf0815abb31841109cf3af',
#   'title': 'Texmo Pipes Standalone December 2023 Net Sales at Rs 122.47 crore, down 40.66% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c21194c119ff6e57a435dd',
#   'title': "CDP awards Electrolux Group ''A'' for climate leadership",
#   'category': 'company_business_news'},
#  {'id': '65c1d495c119ff6e57a40b6c',
#   'title': 'TriumphPay Announces Addition of Two New Hires to Sales Leadership Team',
#   'category': 'company_business_news'},
#  {'id': '65c1d430c119ff6e57a40654',
#   'title': 'VALEO PHARMA AMENDS AGREEMENT WITH NOVARTIS PHARMACEUTICALS CANADA FOR (Pr)XIIDRA® IN CANADA AND CREDIT FACILITY WITH SAGARD HEALTHCARE ROYALTY PARTNERS, LP',
#   'category': 'company_business_news'},
#  {'id': '65cc2cd506df7536a8f68438',
#   'title': 'Power Finance Corp Share Price Live blog for 14 Feb 2024 | Mint',
#   'category': 'market_news'},
#  {'id': '65cecff0abb31841109ce769',
#   'title': 'Ahluwalia Contracts (India) consolidated net profit rises 57.02% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65c98a1bf4fc8477f2ed7c70',
#   'title': 'Century Communities (NYSE:CCS) Has Announced That It Will Be Increasing Its Dividend To $0.26',
#   'category': 'market_news'},
#  {'id': '65cdef0aabb31841109ce40d',
#   'title': 'Lighthouse Expands Into Distribution With Acquisition of Stardekk',
#   'category': 'company_business_news'},
#  {'id': '65c2f2cec119ff6e57a43c89',
#   'title': 'Enphase sees demand improving in near term, shares jump',
#   'category': 'market_news'},
#  {'id': '65cc2d5206df7536a8f68a21',
#   'title': '3 Doomed Meme Stocks to Dump Before They Dive: February 2024',
#   'category': 'market_news'},
#  {'id': '65c1d53ec119ff6e57a41400',
#   'title': "Intel's AI Business Is All Hype -- Here's the Real Reason for Optimism in 2024",
#   'category': 'market_news'},
#  {'id': '65cdb6a5abb31841109ce06f',
#   'title': 'Parsvnath Landmark Developers Pvt reports standalone net loss of Rs 2.85 crore in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65c1d3b4c119ff6e57a40019',
#   'title': 'What To Expect From BellRing Brands’s (BRBR) Q1 Earnings',
#   'category': 'market_news'},
#  {'id': '65cd7eb9abb31841109cd903',
#   'title': 'Kintara Therapeutics Announces Fiscal 2024 Second Quarter Financial Results and Provides Corporate Update',
#   'category': 'company_business_news'},
#  {'id': '65c211a0c119ff6e57a43673',
#   'title': 'HSBC Digital Transformation Strategy Insights Report 2023: Innovation Programs, Technology Initiatives, Estimated ICT Budget, and Major ICT Contracts',
#   'category': 'company_business_news'},
#  {'id': '65c595d161e5050757966cc9',
#   'title': "CJ 4DPLEX's Premium Format 4DX Surpasses $49.6 Million in 2023 in the U.S. Market Topping Previous Year's Box Office",
#   'category': 'company_business_news'},
#  {'id': '65cdeee9abb31841109ce2b1',
#   'title': 'Glenmark Pharmaceuticals Ltd drops for fifth straight session | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65cc6546abb31841109ccea6',
#   'title': 'Jubilant HollisterStier Allergy names new CEO',
#   'category': 'company_business_news'},
#  {'id': '65c7577af4fc8477f2ed7312',
#   'title': 'TransMedics Group Inc Director Edward Basile Sells 7,157 Shares',
#   'category': 'company_business_news'},
#  {'id': '65c83893f4fc8477f2ed7637',
#   'title': 'With 63% ownership, insiders at Clairvest Group Inc. (TSE:CVG) are pretty optimistic and have been buying recently',
#   'category': 'company_business_news'},
#  {'id': '65cadbcff4fc8477f2ed892a',
#   'title': 'Earnings Growth & Price Strength Make Microsoft (MSFT) a Stock to Watch',
#   'category': 'market_news'},
#  {'id': '65c1d60bc119ff6e57a41e63',
#   'title': 'Quotes: Regional bank selloff continues as New York Community Bancorp slumps',
#   'category': 'market_news'},
#  {'id': '65cc2d0b06df7536a8f68676',
#   'title': 'Bright Horizons Family Solutions Inc (BFAM) Reports Mixed Results for Q4 and Full Year 2023',
#   'category': 'company_business_news'},
#  {'id': '65ced04fabb31841109cece0',
#   'title': 'Brookfield, CVC Weigh Bids for Barclays Merchant Payments Unit',
#   'category': 'economic_policies_trends'},
#  {'id': '65c595fe61e5050757966f1f',
#   'title': "CJ 4DPLEX's Premium Format 4DX Surpasses $49.6 Million in 2023 in the U.S. Market Topping Previous Year's Box Office",
#   'category': 'company_business_news'},
#  {'id': '65c5cd9a61e50507579671c1',
#   'title': 'Volumes jump at Aptus Value Housing Finance India Ltd counter',
#   'category': 'market_news'},
#  {'id': '65c32acac119ff6e57a44265',
#   'title': "India's Paytm shares jump after reports CEO met RBI, finance minister",
#   'category': 'economic_policies_trends'},
#  {'id': '65c98a05f4fc8477f2ed7b52',
#   'title': 'Why the 1960s can help us understand our confusing economic mood',
#   'category': 'economic_policies_trends'},
#  {'id': '65cb4c0e8c9dc047f1e041f2',
#   'title': 'Valleyfair to Hire 1,600 Seasonal Associates for 2024 Season',
#   'category': 'company_business_news'},
#  {'id': '65c1d582c119ff6e57a41776',
#   'title': 'Abeona Therapeutics Announces New Employee Inducement Grants Under Nasdaq Listing Rule 5635(c)(4)',
#   'category': 'company_business_news'},
#  {'id': '65bb418ff3aa2a77a58bfc76',
#   'title': 'Paytm crashes over 20%, takes Rs 585-crore toll on fund houses, insurance companies',
#   'category': 'market_news'},
#  {'id': '65cdb6c3abb31841109ce11f',
#   'title': 'Asia-Pacific Data Centre Association Elects its Inaugural Chair of the Board',
#   'category': 'company_business_news'},
#  {'id': '65c605caf4fc8477f2ed6598',
#   'title': 'Trent’s dream run continues…thanks to Zudio!',
#   'category': 'company_business_news'},
#  {'id': '65c595c061e5050757966bee',
#   'title': 'FRN Variable Rate Fix',
#   'category': 'market_news'},
#  {'id': '65c443e3da99411d47476ac2',
#   'title': 'Big Oil offers record returns to lure investors back',
#   'category': 'market_news'},
#  {'id': '65c98a03f4fc8477f2ed7b2d',
#   'title': 'WRAPUP 3-Israel strikes Rafah refugee camp, 37 killed, local health officials say',
#   'category': 'non_financial'},
#  {'id': '65c1d59fc119ff6e57a418fb',
#   'title': "Thousands of accounts at India's Paytm Payments Bank set up improperly",
#   'category': 'economic_policies_trends'},
#  {'id': '65c6e762f4fc8477f2ed700c',
#   'title': 'Disc Medicine Receives FDA Orphan Drug Designation for DISC-3405 for the Treatment of Polycythemia Vera',
#   'category': 'company_business_news'},
#  {'id': '65c32a9ec119ff6e57a44198',
#   'title': 'Jubilant Pharmova declines after US FDA issues 4 observations to Roorkee facility',
#   'category': 'company_business_news'},
#  {'id': '65cc9dd6abb31841109cd25e',
#   'title': 'Adani Green Energy likely to tap dollar bond market in March: Sources',
#   'category': 'market_news'},
#  {'id': '65c6e6cff4fc8477f2ed692e',
#   'title': 'Jain Irrigation Standalone December 2023 Net Sales at Rs 805.28 crore, down 18.07% Y-o-Y',
#   'category': 'company_business_news'},
#  {'id': '65c1a0e4c119ff6e57a3f353',
#   'title': 'Grandma Trading & Agencies reports standalone net profit of Rs 0.03 crore in the December 2023 quarter',
#   'category': 'company_business_news'},
#  {'id': '65c47c22da99411d47477572',
#   'title': 'Paytm Payments Bank and RBI ban: What went wrong and the story so far',
#   'category': 'economic_policies_trends'},
#  {'id': '65cdb6bbabb31841109ce0c3',
#   'title': 'Modern Mills Holders Seeking to Raise $314 Million in Saudi IPO',
#   'category': 'company_business_news'},
#  {'id': '65ced073abb31841109ceec8',
#   'title': 'Diebold Nixdorf, Incorporated (NYSE:DBD) Q4 2023 Earnings Call Transcript',
#   'category': 'company_business_news'},
#  {'id': '65c5cd8d61e5050757967131',
#   'title': 'CBDC: Has RBI monetary policy injected a new life into the digital currency?',
#   'category': 'economic_policies_trends'},
#  {'id': '65c83881f4fc8477f2ed7557',
#   'title': 'Sam Altman and Elon Musk are ‘playing a game of one-upmanship’ in an era of ‘absurdist capitalism,’ says ex-Facebook exec',
#   'category': 'company_business_news'},
#  {'id': '65cadb5ff4fc8477f2ed840c',
#   'title': 'Use airport metro, magenta line: Delhi airport issues traffic advisory ahead of farmer protest',
#   'category': 'non_financial'},
#  {'id': '65cd7ef3abb31841109cdbed',
#   'title': 'Labatt Breweries brings together opposing parties for 3rd annual brewing competition',
#   'category': 'company_business_news'},
#  {'id': '65c2f2d1c119ff6e57a43cb6',
#   'title': 'AllianceBernstein (AB) Just Flashed Golden Cross Signal: Do You Buy?',
#   'category': 'market_news'},
#  {'id': '65c605ccf4fc8477f2ed65ac',
#   'title': 'Zydus Wellness Standalone December 2023 Net Sales at Rs 63.80 crore, up 0.13% Y-o-Y',
#   'category': 'company_business_news'},
#  {'id': '65c08789c119ff6e57a3f024',
#   'title': 'Govt working on improving credibility of official data, says finance minister Nirmala Sitharaman | Mint',
#   'category': 'economic_policies_trends'},
#  {'id': '65bb0948f3aa2a77a58bf89e',
#   'title': 'Graphite India Share Price Live blog for 01 Feb 2024 | Mint',
#   'category': 'market_news'},
#  {'id': '65c6e6d5f4fc8477f2ed698e',
#   'title': 'Confusion and concern: Traders brace for impact of Paytm crisis',
#   'category': 'economic_policies_trends'},
#  {'id': '65bc93b3f3aa2a77a58c02ff',
#   'title': 'Titan shares at ₹3,290 or ₹4,200? Analysts revise price targets on Q3 margin miss',
#   'category': 'market_news'},
#  {'id': '65c595cc61e5050757966c8d',
#   'title': 'Athira Pharma Announces Publication in Frontiers in Neuroscience Highlighting Therapeutic Potential of ATH-1105 in Amyotrophic Lateral Sclerosis (ALS)',
#   'category': 'company_business_news'},
#  {'id': '65c7574cf4fc8477f2ed72c9',
#   'title': 'Mukand consolidated net profit rises 3.25% in the December 2023 quarter',
#   'category': 'company_business_news'},
#  {'id': '65c87084f4fc8477f2ed7728',
#   'title': 'Why should you include debt instruments in your portfolios? Here are 5 key reasons | Mint',
#   'category': 'personal_finance'},
#  {'id': '65cc2d3206df7536a8f68870',
#   'title': 'Rush Enterprises: Q4 Earnings Snapshot',
#   'category': 'company_business_news'},
#  {'id': '65c3630417f2c04a90ee4f8a',
#   'title': 'QUOTES-Reactions to China replacing the head of securities regulator',
#   'category': 'economic_policies_trends'},
#  {'id': '65ced026abb31841109cead4',
#   'title': 'Procore Announces Fourth Quarter and Full Year 2023 Financial Results',
#   'category': 'company_business_news'},
#  {'id': '65c98a00f4fc8477f2ed7b0a',
#   'title': "Here's Why We Think Construction Partners (NASDAQ:ROAD) Is Well Worth Watching",
#   'category': 'market_news'},
#  {'id': '65cd7e78abb31841109cd591',
#   'title': 'Ashiana Housing consolidated net profit rises 207.18% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'company_business_news'},
#  {'id': '65c4b49a61e505075796655a',
#   'title': 'Share Buyback Transaction Details February 1 – 7, 2024',
#   'category': 'company_business_news'},
#  {'id': '65cc2d1b06df7536a8f68746',
#   'title': 'CapitaLand Investment establishes CapitaLand Ascott Residence Asia Fund II to invest in lodging properties amidst growing demand',
#   'category': 'company_business_news'},
#  {'id': '65c5956561e50507579667c3',
#   'title': 'Quint Digital standalone net profit rises 5.73% in the December 2023 quarter',
#   'category': 'company_business_news'},
#  {'id': '65cadb9df4fc8477f2ed869c',
#   'title': 'Bob Moore, founder of Bob’s Red Mill, has died',
#   'category': 'company_business_news'},
#  {'id': '65ced074abb31841109ceed8',
#   'title': 'Net Asset Value(s)',
#   'category': 'company_business_news'},
#  {'id': '65c8384df4fc8477f2ed7396',
#   'title': 'Garena Free Fire Max redeem codes for February 11, 2024: Claim free in-game goodies | Mint',
#   'category': 'non_financial'},
#  {'id': '65cd7e71abb31841109cd4f2',
#   'title': 'Repco Home Finance consolidated net profit rises 25.06% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'company_business_news'},
#  {'id': '65ced099abb31841109cf0be',
#   'title': "Meta's Facebook, Instagram to charge Apple service fee for posts 'boosted' via iOS apps",
#   'category': 'company_business_news'},
#  {'id': '65cc2cd506df7536a8f6843d',
#   'title': 'TATA TECHNOLOGIES Share Price Live blog for 14 Feb 2024 | Mint',
#   'category': 'market_news'},
#  {'id': '65c605e9f4fc8477f2ed66f6',
#   'title': 'Bang Overseas Consolidated December 2023 Net Sales at Rs 36.82 crore, up 21.95% Y-o-Y',
#   'category': 'company_business_news'},
#  {'id': '65c04f5bc119ff6e57a3ef69',
#   'title': 'Dhampur Sugar Mills consolidated net profit declines 31.52% in the December 2023 quarter',
#   'category': 'company_business_news'},
#  {'id': '65c1a0d6c119ff6e57a3f279',
#   'title': 'Nifty 50, Sensex today: What to expect from Indian stock market in trade on February 6 | Mint',
#   'category': 'market_news'},
#  {'id': '65c1d6e0c119ff6e57a42954',
#   'title': 'Still love your landline? Phone service providers are getting closer to phasing it out',
#   'category': 'company_business_news'},
#  {'id': '65cc2d1306df7536a8f686e7',
#   'title': 'BRET MICHAELS PARTNERS WITH LIVE NATION FOR THE TRIUMPHANT RETURN OF THE MICHAELS-PRODUCED & CREATED PARTI-GRAS 2.0, THE ALL-KILLER HITS, NO FILLER, FEEL-GOOD MUSIC FESTIVAL OF THE SUMMER',
#   'category': 'non_financial'},
#  {'id': '65c6e6e2f4fc8477f2ed6aa1',
#   'title': 'China South City flags potential default on Oct 2024 notes payment',
#   'category': 'economic_policies_trends'},
#  {'id': '65c362fe17f2c04a90ee4f52',
#   'title': 'ASSA ABLOY Quarterly Report Q4 2023',
#   'category': 'market_news'},
#  {'id': '65c9fa4df4fc8477f2ed809b',
#   'title': 'Mutual funds: Investing ₹1 lakh at the time of launch would have grown to ₹34 lakh in 24 years | Mint',
#   'category': 'personal_finance'},
#  {'id': '65c4441eda99411d47476cb7',
#   'title': 'Holding(s) in Company',
#   'category': 'company_business_news'},
#  {'id': '65c4448eda99411d47477257',
#   'title': 'Compass Minerals (CMP) Q1 Earnings and Revenues Miss Estimates',
#   'category': 'market_news'},
#  {'id': '65ced08babb31841109ceffc',
#   'title': 'Bitcoin Tops 52,000: 5 ETFs Leading the Rally',
#   'category': 'market_news'},
#  {'id': '65cd7ed3abb31841109cda47',
#   'title': 'Graham Halonen Joins PSM Partners, LLC as Practice Manager of Talent Services',
#   'category': 'company_business_news'},
#  {'id': '65cd7e86abb31841109cd65e',
#   'title': 'Akamai (AKAM) Q4 Earnings Beat Estimates on Higher Revenues',
#   'category': 'market_news'},
#  {'id': '65c2118ac119ff6e57a43563',
#   'title': 'Cisco and NVIDIA to Help Enterprises Quickly and Easily Deploy and Manage Secure AI Infrastructure',
#   'category': 'company_business_news'},
#  {'id': '65c44460da99411d47477008',
#   'title': 'Crown Holdings, Inc. (NYSE:CCK) Q4 2023 Earnings Call Transcript',
#   'category': 'market_news'},
#  {'id': '65cd7ebdabb31841109cd93c',
#   'title': 'Business Expansion: U-Haul Acquires Advantage Storage in Hobbs',
#   'category': 'company_business_news'},
#  {'id': '65bccb4bf3aa2a77a58c0336',
#   'title': 'Jana Small Finance Bank IPO opens next week. Price band fixed at ₹393 to ₹414 per share | Mint',
#   'category': 'market_news'},
#  {'id': '65cd7ea1abb31841109cd7c9',
#   'title': 'Hempel buying another well-known downtown Minneapolis building',
#   'category': 'company_business_news'},
#  {'id': '65cadb69f4fc8477f2ed84a8',
#   'title': 'Cenlub Industries standalone net profit declines 31.07% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65c47c51da99411d474775a7',
#   'title': 'McKesson (MCK) Q3 2024 Earnings Call Transcript',
#   'category': 'market_news'},
#  {'id': '65bc5acbf3aa2a77a58c0003',
#   'title': 'Apple China sales lag overshadows quarterly profit, revenue beats | Mint',
#   'category': 'market_news'},
#  {'id': '65c87089f4fc8477f2ed7737',
#   'title': "GBPUSD Perched Above $1.26; BoE's Mann Warns Of Upside Shocks To British Inflation | Capital Market News - Business Standard",
#   'category': 'market_news'},
#  {'id': '65c1d72bc119ff6e57a42d1f',
#   'title': 'US House panel recommends $17.6 billion in military aid for Israel',
#   'category': 'economic_policies_trends'},
#  {'id': '65bb79d9f3aa2a77a58bff13',
#   'title': 'No hike in home loan interest deduction limit in Interim Budget 2024',
#   'category': 'economic_policies_trends'},
#  {'id': '65cc2cec06df7536a8f685ad',
#   'title': 'How to Get Auto Loan Debt Relief',
#   'category': 'personal_finance'},
#  {'id': '65c83857f4fc8477f2ed7472',
#   'title': 'Neuland Laboratories consolidated net profit rises 166.42% in the December 2023 quarter',
#   'category': 'market_news'},
#  {'id': '65cd7ebeabb31841109cd93f',
#   'title': 'CF (CF) Q4 Earnings: Taking a Look at Key Metrics Versus Estimates',
#   'category': 'market_news'},
#  {'id': '65c5960b61e5050757966fbf',
#   'title': "Super Bowl LVIII's Super School Meals Celebrates Completion of 58-School Effort to Tackle Food Insecurity Among Nevada Youth",
#   'category': 'non_financial'},
#  {'id': '65c1d3adc119ff6e57a3ffc0',
#   'title': 'Tech stocks fuel market surge as jobs report underscores economy’s resilience',
#   'category': 'market_news'},
#  {'id': '65c1d3ddc119ff6e57a40223',
#   'title': 'Storm Lashes California as Rains Bring Dangerous Flood Risk',
#   'category': 'non_financial'},
#  {'id': '65cc2d1c06df7536a8f68756',
#   'title': 'Dungeons & Dragons Celebrates 50th Anniversary in 2024 with More than 50 Million Fans',
#   'category': 'non_financial'},
#  {'id': '65c1d4c0c119ff6e57a40d9a',
#   'title': 'What Is A Purple Squirrel In Recruiting?',
#   'category': 'non_financial'},
#  {'id': '65c44435da99411d47476dd9',
#   'title': 'Roblox (RBLX) Q4 2023 Earnings Call Transcript',
#   'category': 'market_news'},
#  {'id': '65cc6520abb31841109ccd97',
#   'title': "Gensol wins PLI bid for advanced Electrolyser Plant under India's green hydrogen mission | Capital Market News - Business Standard",
#   'category': 'economic_policies_trends'},
#  {'id': '65ced033abb31841109ceb7f',
#   'title': 'Ares Management Corporation to Present at the BofA Securities Financial Services Conference 2024',
#   'category': 'market_news'},
#  {'id': '65c44454da99411d47476f64',
#   'title': 'NYCB in Talks to Offload Mortgage Risk, Exploring Loan Sales',
#   'category': 'market_news'},
#  {'id': '65c2f261c119ff6e57a4384a',
#   'title': 'Can go to NCLT to enforce Sony merger deal after SIAC rejects petition: Zee',
#   'category': 'company_business_news'},
#  {'id': '65c32ac0c119ff6e57a441f2',
#   'title': "US News Ranks NJIT Top 100 in Two Online Master's Programs",
#   'category': 'non_financial'},
#  {'id': '65c44449da99411d47476ee7',
#   'title': 'How to read your credit card statement',
#   'category': 'personal_finance'},
#  {'id': '65bc5ac1f3aa2a77a58bffd5',
#   'title': 'Day trading guide for stock market today: Seven stocks to buy or sell on Friday — 2nd February | Mint',
#   'category': 'market_news'},
#  {'id': '65cadb8ef4fc8477f2ed85db',
#   'title': 'CANADA STOCKS-TSX inches up ahead of US inflation data',
#   'category': 'market_news'},
#  {'id': '65c5960f61e5050757966ff2',
#   'title': 'Industrial Air Chiller Market Anticipated to Reach $6.17 Billion by 2028, Fueled by Pharmaceutical Sector Growth and Food & Beverage Industry Demand',
#   'category': 'market_news'},
#  {'id': '65bccb44f3aa2a77a58c031e',
#   'title': 'KELTECH Energ Standalone December 2023 Net Sales at Rs 95.62 crore, down 36.71% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c362cc17f2c04a90ee4dea',
#   'title': 'Redington Consolidated December 2023 Net Sales at Rs 23,504.97 crore, up 8.45% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c5cd8b61e5050757967126',
#   'title': "Yes Bank shares jump after SBI's rebuttal on profit-booking reports. Buy or sell? | Mint",
#   'category': 'market_news'},
#  {'id': '65c32a95c119ff6e57a4411f',
#   'title': 'Kotak Mahindra Bank gains as CCI clears Zurich Insurance to buy 70% in general insurance arm',
#   'category': 'company_business_news'},
#  {'id': '65cd7ec3abb31841109cd97f',
#   'title': 'NerdWallet Reports Fourth Quarter and Full Year 2023 Results',
#   'category': 'company_business_news'},
#  {'id': '65c08785c119ff6e57a3f015',
#   'title': 'RBI Monetary Policy Committee (MPC) meeting: Check the date, time, and where to watch here | Mint',
#   'category': 'economic_policies_trends'},
#  {'id': '65c362c317f2c04a90ee4dc1',
#   'title': 'Top Gainers and Losers today on 7 February, 2024: State Bank Of India, Grasim Industries, Tech Mahindra, Power Grid Corporation Of India among most active stocks; Check full list here | Mint',
#   'category': 'market_news'},
#  {'id': '65cadb67f4fc8477f2ed848c',
#   'title': 'Jatalia Global Ventures reports standalone net loss of Rs 0.01 crore in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65ced051abb31841109cecfd',
#   'title': 'Carahsoft Hosts Google Cloud Healthcare Symposium at the Carahsoft Conference and Collaboration Center in Reston, VA on Feb. 27',
#   'category': 'company_business_news'},
#  {'id': '65c44470da99411d474770db',
#   'title': 'SiMa.ai Recognized as an IDC Innovator for AI/ML at the Edge',
#   'category': 'company_business_news'},
#  {'id': '65c60610f4fc8477f2ed685f',
#   'title': "Neurocrine Biosciences Inc's Chief Commercial Officer Eric Benevich Sells Company Shares",
#   'category': 'market_news'},
#  {'id': '65cd7e64abb31841109cd3c4',
#   'title': 'Global Payments Inc misses annual revenue forecast',
#   'category': 'market_news'},
#  {'id': '65c5959d61e5050757966a22',
#   'title': 'Wenchang, Hainan Takes Flight as the Visionary "City of the Future" Igniting a Thriving Aerospace Industry',
#   'category': 'non_financial'},
#  {'id': '65c5954b61e5050757966617',
#   'title': 'Nestle India Share Price Live blog for 09 Feb 2024 | Mint',
#   'category': 'market_news'},
#  {'id': '65bb79d3f3aa2a77a58bfed9',
#   'title': "Anand Mahindra's 4 big takeaways from Budget 2024",
#   'category': 'economic_policies_trends'},
#  {'id': '65c32a8bc119ff6e57a440c7',
#   'title': 'Hariyana Vent. Standalone December 2023 Net Sales at Rs 0.83 crore, down 7.78% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c2f2fac119ff6e57a43edf',
#   'title': 'Nabors Industries Ltd (NBR) Reports Improved Financials Amidst Market Challenges',
#   'category': 'company_business_news'},
#  {'id': '65cc9d85abb31841109cd15d',
#   'title': 'Numab Therapeutics and Ono Pharmaceutical Announce an Option and Collaboration Agreement to Develop Multi-specific Antibody NM49 for Treatment of Cancer',
#   'category': 'company_business_news'},
#  {'id': '65c1d43fc119ff6e57a40711',
#   'title': 'Bit Brother Limited Receives Notice of Delisting from Nasdaq',
#   'category': 'market_news'},
#  {'id': '65c1d6f4c119ff6e57a42a59',
#   'title': 'Bullish QEM Insiders Loaded Up On AU$835.2k Of Stock',
#   'category': 'market_news'},
#  {'id': '65c1d33ec119ff6e57a3fa34',
#   'title': 'Meshy-2 Unveils Text to 3D Brilliance: Elevate Creativity with High-Quality Texture and Geometry',
#   'category': 'company_business_news'},
#  {'id': '65cadbc9f4fc8477f2ed88e3',
#   'title': 'Beamr Imaging Ltd. Announces Pricing of $12 Million Public Offering',
#   'category': 'market_news'},
#  {'id': '65c1d4dac119ff6e57a40eec',
#   'title': 'How major US stock indexes fared Friday, 2/2/2024',
#   'category': 'market_news'},
#  {'id': '65c83850f4fc8477f2ed73da',
#   'title': 'Artificial intelligence driving more layoffs than companies want to admit',
#   'category': 'company_business_news'},
#  {'id': '65cdeeeeabb31841109ce2dc',
#   'title': 'Hind Composites Standalone December 2023 Net Sales at Rs 71.69 crore, up 3.26% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65cb4bfb8c9dc047f1e0410f',
#   'title': 'Global Probiotic Drinks Market Size To Worth USD 98.52 Billion By 2033 | CAGR of 9.5%',
#   'category': 'market_news'},
#  {'id': '65cd7efaabb31841109cdc48',
#   'title': 'Mexican retailer Walmex posts slight profit bump in fourth quarter',
#   'category': 'company_business_news'},
#  {'id': '65cd7e5aabb31841109cd31d',
#   'title': 'Hindalco Share Price Live blog for 15 Feb 2024 | Mint',
#   'category': 'market_news'},
#  {'id': '65c989fbf4fc8477f2ed7ae1',
#   'title': 'Sriracha mogul David Tran is a 78-year-old immigrant turned multimillionaire—and now his empire is in peril',
#   'category': 'company_business_news'},
#  {'id': '65c2f2e0c119ff6e57a43d82',
#   'title': 'BAE Systems Acquires Malloy Aeronautics',
#   'category': 'company_business_news'},
#  {'id': '65c605d3f4fc8477f2ed65d8',
#   'title': 'Kilburn Engg Standalone December 2023 Net Sales at Rs 72.80 crore, up 35.27% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65cc2d4a06df7536a8f689b3',
#   'title': 'Dow tumbles more than 700 points after hot inflation report',
#   'category': 'market_news'},
#  {'id': '65c4442fda99411d47476d90',
#   'title': 'Blue World Acquisition Corporation Announces Extension of the Deadline for an Initial Business Combination',
#   'category': 'company_business_news'},
#  {'id': '65c6e764f4fc8477f2ed7024',
#   'title': 'Annaly Capital Management, Inc. (NYSE:NLY) Q4 2023 Earnings Call Transcript',
#   'category': 'market_news'},
#  {'id': '65c1d90bc119ff6e57a433f9',
#   'title': 'Buy Bank of Baroda; target of Rs 270: Prabhudas Lilladher',
#   'category': 'personal_finance'},
#  {'id': '65c1d7a2c119ff6e57a43353',
#   'title': 'Ansys to Release Fourth Quarter and FY 2023 Earnings on February 21, 2024',
#   'category': 'company_business_news'},
#  {'id': '65c2f310c119ff6e57a4400f',
#   'title': "UPDATE 1-Brazil's govt aims to erase fiscal deficit this year without expense block, says Haddad",
#   'category': 'economic_policies_trends'},
#  {'id': '65cd7eadabb31841109cd868',
#   'title': 'AM Best Maintains Under Review With Negative Implications Status for Credit Ratings of Universal North America Insurance Company',
#   'category': 'company_business_news'},
#  {'id': '65c6e712f4fc8477f2ed6bd2',
#   'title': 'Asia-Pacific Edtech Focused Insights Report 2024: A Projected $318.65 Billion Market by 2028 - Companies Focus on User Engagement and Skill-Building Tools to Stay Competitive',
#   'category': 'company_business_news'},
#  {'id': '65ced06cabb31841109cee70',
#   'title': 'DOJ probe finds nearly 200 federal prison suicides preventable',
#   'category': 'non_financial'},
#  {'id': '65c6e6dcf4fc8477f2ed6a40',
#   'title': 'Focus: After months of negotiation, a rare Russian compromise as Yandex changes hands',
#   'category': 'company_business_news'},
#  {'id': '65c5960161e5050757966f3f',
#   'title': 'Digital Health Leader Joins Leavitt Partners',
#   'category': 'company_business_news'},
#  {'id': '65c1d61bc119ff6e57a41f31',
#   'title': 'Presidio Trust Commercial Leasing Ends 2023 with 97% Occupancy Rate',
#   'category': 'company_business_news'},
#  {'id': '65cd7e95abb31841109cd731',
#   'title': 'How to use Fibonacci Levels to be a Better Stock Trader',
#   'category': 'personal_finance'},
#  {'id': '65cc9d7eabb31841109cd10e',
#   'title': "Multitude SE - Managers' transactions - Vella",
#   'category': 'company_business_news'},
#  {'id': '65c2f309c119ff6e57a43fa5',
#   'title': 'Stemson Therapeutics Announces Technological Breakthrough in New Hair Growth',
#   'category': 'company_business_news'},
#  {'id': '65cc2d1d06df7536a8f68765',
#   'title': 'Network Attached Storage Market Size Worth $138.03 Billion by 2033 - Rising Investment in 5G Technology to Propel Growth',
#   'category': 'market_news'},
#  {'id': '65c9fa8bf4fc8477f2ed8248',
#   'title': 'Ship in Red Sea Signals All-Muslim Crew to Avoid Houthi Attack',
#   'category': 'company_business_news'},
#  {'id': '65cadbc6f4fc8477f2ed88b9',
#   'title': 'Total Voting Rights',
#   'category': 'company_business_news'},
#  {'id': '65c211a6c119ff6e57a436bf',
#   'title': 'AudioCodes: Q4 Earnings Snapshot',
#   'category': 'market_news'},
#  {'id': '65c44473da99411d47477101',
#   'title': "Here's What Key Metrics Tell Us About FleetCor Technologies (FLT) Q4 Earnings",
#   'category': 'company_business_news'},
#  {'id': '65c2f298c119ff6e57a439cd',
#   'title': 'CACI to Participate in Citi 2024 Global Industrial Tech and Mobility Conference',
#   'category': 'company_business_news'},
#  {'id': '65c6e6e2f4fc8477f2ed6aa1',
#   'title': 'China South City flags potential default on Oct 2024 notes payment',
#   'category': 'market_news'},
#  {'id': '65c44474da99411d47477110',
#   'title': 'Cirium: International Travel Resumes This Spring Festival to China’s Top International Markets of Thailand, Japan and South Korea',
#   'category': 'company_business_news'},
#  {'id': '65cc2d1406df7536a8f686f2',
#   'title': 'Loss-Making Flywire Corporation (NASDAQ:FLYW) Set To Breakeven',
# ...
#   'category': 'market_news'},
#  {'id': '65c5955e61e505075796673c',
#   'title': 'Arrest of Chanda Kochhar, husband in ICICI-Videocon loan case illegal: HC',
#   'category': 'company_business_news'},
#  {'id': '65c6e71bf4fc8477f2ed6c45',
#   'title': 'Haemonetics (HAE) Q3 Earnings Top Estimates, 2024 View Raised',
#   'category': 'market_news'},
#  {'id': '65cadbc2f4fc8477f2ed8883',
#   'title': 'Seeking Clues to AtriCure (ATRC) Q4 Earnings? A Peek Into Wall Street Projections for Key Metrics',
#   'category': 'market_news'},
#  {'id': '65cc6547abb31841109cceb0',
#   'title': 'GRAPHIC-Looming election puts battered British markets back in the spotlight',
#   'category': 'market_news'},
#  {'id': '65c5cdc661e5050757967276',
#   'title': 'Grab, GoTo revive talks for ride-hailing merger -Bloomberg News',
#   'category': 'company_business_news'},
#  {'id': '65c2f288c119ff6e57a4390b',
#   'title': '3 Buy-Rated Stocks Outperforming the Magnificent 7',
#   'category': 'market_news'},
#  {'id': '65cc9d50abb31841109ccf63',
#   'title': 'Mahindra & Mahindra Q3 results: Net profit jumps 60% YoY to Rs 2,454 crore on healthy topline',
#   'category': 'market_news'},
#  {'id': '65c443e1da99411d47476ab1',
#   'title': 'RBI policy to be announced today: 6 important things to watch out for in MPC meeting outcome | Mint',
#   'category': 'economic_policies_trends'},
#  {'id': '65cadbb2f4fc8477f2ed87ab',
#   'title': 'Countdown to Appian (APPN) Q4 Earnings: A Look at Estimates Beyond Revenue and EPS',
#   'category': 'market_news'},
#  {'id': '65ced006abb31841109ce935',
#   'title': 'Handicapping the Earnings Outlook',
#   'category': 'market_news'},
#  {'id': '65cc2d4706df7536a8f68987',
#   'title': 'Angi (NASDAQ:ANGI) Misses Q4 Revenue Estimates, But Stock Soars 7%',
#   'category': 'market_news'},
#  {'id': '65c1d706c119ff6e57a42b47',
#   'title': 'The ‘beauty bubble’ is real. Just ask the man who’s been studying the link between being hot and making more money for 30 years',
#   'category': 'personal_finance'},
#  {'id': '65c4b48861e5050757966482',
#   'title': 'Bybit Spot Grid 3.0: Better Crypto Trading with Enhanced Automation',
#   'category': 'personal_finance'},
#  {'id': '65c595b761e5050757966b77',
#   'title': 'Exxon Mobil to Exit Equatorial Guinea',
#   'category': 'company_business_news'},
#  {'id': '65cadbccf4fc8477f2ed890d',
#   'title': 'Ramco Systems launches Ramco Payce, a revolutionary platform-based payroll software',
#   'category': 'company_business_news'},
#  {'id': '65c6e771f4fc8477f2ed70d2',
#   'title': 'Why Lumen Stock Is Jumping This Week',
#   'category': 'market_news'},
#  {'id': '65c443f3da99411d47476bcb',
#   'title': 'Gyan Developers & Builders reports standalone net loss of Rs 0.02 crore in the December 2023 quarter',
#   'category': 'market_news'},
#  {'id': '65cadbc6f4fc8477f2ed88b0',
#   'title': 'Teck’s Red Dog Operations Achieves Zinc Mark Verification',
#   'category': 'company_business_news'},
#  {'id': '65c8389ef4fc8477f2ed76b2',
#   'title': 'Southwest Washington Dance Center hires new artistic director',
#   'category': 'non_financial'},
#  {'id': '65c6e739f4fc8477f2ed6dcd',
#   'title': 'First Financial Bank Announces Promotion of Blaine Caillier to Regional President of First Financial Bank, Southeast Region',
#   'category': 'company_business_news'},
#  {'id': '65c989d0f4fc8477f2ed792c',
#   'title': 'How stock experts minted money from TV shows',
#   'category': 'market_news'},
#  {'id': '65c32acdc119ff6e57a44289',
#   'title': 'American Healthcare REIT to raise about $672 mln in US IPO',
#   'category': 'market_news'},
#  {'id': '65c1d500c119ff6e57a410e5',
#   'title': 'Armada Mortgage Corp. Announces Increase in Dividend',
#   'category': 'company_business_news'},
#  {'id': '65ced009abb31841109ce962',
#   'title': 'Fairview Microwave Unveils Phase Shifters and Continuously Variable Attenuators',
#   'category': 'company_business_news'},
#  {'id': '65cel009abb31841109ce962',
#   'title': 'Fairview Microwave Unveils Phase Shifters and Continuously Variable Attenuators',
#   'category': 'company_business_news'},
#  {'id': '65cdeefaabb31841109ce334',
#   'title': 'FOREX-Dollar steady before data; yen slips despite GDP surprise',
#   'category': 'market_news'},
#  {'id': '65ced06eabb31841109cee7b',
#   'title': 'Capital régional et coopératif Desjardins announces its financial results',
#   'category': 'company_business_news'},
#  {'id': '65c362d517f2c04a90ee4e3a',
#   'title': 'Prevest Denpro Standalone December 2023 Net Sales at Rs 13.62 crore, up 11.05% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65ced081abb31841109cef79',
#   'title': 'Wilford K. Gibson, MD, FAAOS, Named Second Vice President of American Academy of Orthopaedic Surgeons',
#   'category': 'company_business_news'},
#  {'id': '65cecfe6abb31841109ce692',
#   'title': 'Yield spread between corporate bond and g-sec narrows in February | Economy & Policy News - Business Standard',
#   'category': 'economic_policies_trends'},
#  {'id': '65c47c52da99411d474775b1',
#   'title': 'Why JD.com Stock Followed Alibaba Lower Today',
#   'category': 'market_news'},
#  {'id': '65befdcff3aa2a77a58c0725',
#   'title': 'Absence of surprises in Budget: Mkts flat as investors look for triggers',
#   'category': 'economic_policies_trends'},
#  {'id': '65cc9d4eabb31841109ccf48',
#   'title': 'HDFC Bank share price hits 52-week low, down 20% in 2024 so far | Mint',
#   'category': 'market_news'},
#  {'id': '65c595e561e5050757966dc6',
#   'title': 'eGain Corp (EGAN) Reports Increased Profitability and New Customer Wins in Q2',
#   'category': 'market_news'},
#  {'id': '65c1a0e7c119ff6e57a3f38f',
#   'title': "Ukraine's farm unions ask government to protect free EU market access",
#   'category': 'economic_policies_trends'},
#  {'id': '65c2f268c119ff6e57a438bb',
#   'title': 'Yellen says Congress should provide authority to regulate stablecoins',
#   'category': 'economic_policies_trends'},
#  {'id': '65c9c210f4fc8477f2ed7f76',
#   'title': 'Hariom Pipe Standalone December 2023 Net Sales at Rs 280.00 crore, up 127.91% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c1d60ec119ff6e57a41e89',
#   'title': 'Asphalt Additive Market Report 2024: Global Trends, Forecast and Competitive Analysis 2018-2023 and 2024-2030 Featuring Nouryon, Dow, Arkema, Honeywell International, Evonik, Huntsman, and Kraton',
#   'category': 'market_news'},
#  {'id': '65c44419da99411d47476c73',
#   'title': 'Julius Genachowski and Dawn Ostroff Join Mattel Board of Directors',
#   'category': 'company_business_news'},
#  {'id': '65bb41a4f3aa2a77a58bfd66',
#   'title': 'Thomas Cook Consolidated December 2023 Net Sales at Rs 1,893.13 crore, up 23.22% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65bc931cf3aa2a77a58c02d2',
#   'title': 'Walchandnagar Standalone December 2023 Net Sales at Rs 55.86 crore, down 23.46% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65cecff1abb31841109ce782',
#   'title': 'Pervasive Commodities reports standalone net loss of Rs 0.05 crore in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65bb7a60f3aa2a77a58bff83',
#   'title': "Elon Musk proposes relocation of Tesla's incorporation to Texas, awaits shareholder vote",
#   'category': 'company_business_news'},
#  {'id': '65cdef17abb31841109ce4ba',
#   'title': 'Hunt Considers UK Public Spending Squeeze to Fund Tax Giveaways',
#   'category': 'economic_policies_trends'},
#  {'id': '65c6e782f4fc8477f2ed71c3',
#   'title': 'AAFA Statement on Uber Eats Super Bowl Ad',
#   'category': 'company_business_news'},
#  {'id': '65c1d376c119ff6e57a3fd06',
#   'title': 'Can Clean Harbors, Inc. (NYSE:CLH) Maintain Its Strong Returns?',
#   'category': 'market_news'},
#  {'id': '65ced01babb31841109cea4c',
#   'title': 'Sandstorm Gold Royalties Announces Record 2023 Annual Results',
#   'category': 'company_business_news'},
#  {'id': '65cc2d3f06df7536a8f68914',
#   'title': 'Power Trader Challenges Texas Grid Policy Over Price Spikes',
#   'category': 'economic_policies_trends'},
#  {'id': '65c989e3f4fc8477f2ed7a71',
#   'title': 'Rolcon Engineering Company consolidated net profit rises 252.83% in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65cd7e95abb31841109cd730',
#   'title': 'Global Industrial Sacks Market Outlook & Forecast 2024-2029, with Profiles of Key Players Berry Global, BillerudKorsnas, Mondi, Segezha Group, Smurfit Kappa, Sonoco and Westrock',
#   'category': 'market_news'},
#  {'id': '65cc2cfc06df7536a8f685c4',
#   'title': 'Comstock: Q4 Earnings Snapshot',
#   'category': 'market_news'},
#  {'id': '65ced076abb31841109ceee5',
#   'title': 'Informatica Inc. (NYSE:INFA) Q4 2023 Earnings Call Transcript',
#   'category': 'market_news'},
#  {'id': '65c443eeda99411d47476b8b',
#   'title': 'Canara Bank receives re-validation in credit ratings',
#   'category': 'market_news'},
#  {'id': '65cadb6df4fc8477f2ed84c3',
#   'title': 'PH Trading reports standalone net profit of Rs 0.06 crore in the December 2023 quarter | Capital Market News - Business Standard',
#   'category': 'market_news'},
#  {'id': '65cdb6c2abb31841109ce108',
#   'title': 'Will Energy Resources of Australia (ASX:ERA) Spend Its Cash Wisely?',
#   'category': 'market_news'},
#  {'id': '65c1d453c119ff6e57a4080c',
#   'title': 'OPNX, the Exchange Built by Founders of Doomed Hedge Fund Three Arrows, Is Shutting Down',
#   'category': 'market_news'},
#  {'id': '65c1d44dc119ff6e57a407c8',
#   'title': 'US Homelessness Hits Historic Levels As 653,000 Americans Are Now Homeless Despite Stock Market Reaching All-Time Highs',
#   'category': 'economic_policies_trends'},
#  {'id': '65ced028abb31841109ceaf9',
#   'title': 'Paul Tornetta III, MD, PhD, FAAOS, Named 92nd President of the American Academy of Orthopaedic Surgeons',
#   'category': 'company_business_news'},
#  {'id': '65c32a9bc119ff6e57a44159',
#   'title': "L&T bags 'large' contract for hydrocarbon biz from IndianOil Adani Ventures",
#   'category': 'company_business_news'},
#  {'id': '65c9fa53f4fc8477f2ed80d5',
#   'title': 'RDB Rasayans Standalone December 2023 Net Sales at Rs 25.32 crore, up 7.22% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c5cd9a61e50507579671b2',
#   'title': 'Williamson Financial Services standalone net profit declines 99.34% in the December 2023 quarter',
#   'category': 'market_news'},
#  {'id': '65cb4c078c9dc047f1e041a2',
#   'title': "Nigerian rail projects drive home China's belt and road commitment to African infrastructure development",
#   'category': 'economic_policies_trends'},
#  {'id': '65c211a0c119ff6e57a43676',
#   'title': 'Medical Simulation Market Size to Grow USD 10,634.2 Million by 2033 at a CAGR of 16% | Market.us',
#   'category': 'market_news'},
#  {'id': '65c0bfcbc119ff6e57a3f119',
#   'title': 'Iykot Hitech Standalone December 2023 Net Sales at Rs 0.26 crore, up 17.74% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c5959461e50507579669a2',
#   'title': 'Illinois American Water President Rebecca Losli Named Chairperson of the Illinois Utilities Business Diversity Council',
#   'category': 'company_business_news'},
#  {'id': '65cc2d4206df7536a8f6893d',
#   'title': 'Georgia Association of Accounting Educators holds annual conference at SRTC-Thomasville',
#   'category': 'company_business_news'},
#  {'id': '65c1d638c119ff6e57a420aa',
#   'title': 'Automotive Airbag Sensor Market to grow by USD 220.4 million from 2022 to 2027; Increasing use of MEMS sensors for airbags to be a major trend - Technavio',
#   'category': 'market_news'},
#  {'id': '65c1d42dc119ff6e57a4062a',
#   'title': 'Controlling shareholders bid to take Brazil payments firm Cielo private for $1.2 billion',
#   'category': 'market_news'},
#  {'id': '65bde487f3aa2a77a58c0543',
#   'title': 'Bezos to sell up to 50 million Amazon shares by Jan. 31 next year, filing shows',
#   'category': 'market_news'},
#  {'id': '65c44421da99411d47476cd7',
#   'title': 'Is EMCORE (EMKR) Stock Outpacing Its Computer and Technology Peers This Year?',
#   'category': 'market_news'},
#  {'id': '65c5961a61e505075796708e',
#   'title': 'FRN Variable Rate Fix',
#   'category': 'market_news'},
#  {'id': '65c1d477c119ff6e57a409e9',
#   'title': 'We Ran A Stock Scan For Earnings Growth And Spritzer Bhd (KLSE:SPRITZER) Passed With Ease',
#   'category': 'market_news'},
#  {'id': '65cc9d4dabb31841109ccf44',
#   'title': 'QGO Finance Lim Standalone December 2023 Net Sales at Rs 3.57 crore, up 22.31% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65bb419bf3aa2a77a58bfcf7',
#   'title': 'AksharChem Standalone December 2023 Net Sales at Rs 75.28 crore, up 15.99% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c6e742f4fc8477f2ed6e52',
#   'title': 'Consumers Energy, the Principal Subsidiary of CMS Energy, Declares Quarterly Dividend on Preferred Stock',
#   'category': 'market_news'},
#  {'id': '65cadbdef4fc8477f2ed89f2',
#   'title': 'ZMH adds ESG Veteran Marie-Josee Privyk to the Advisory Board',
#   'category': 'company_business_news'},
#  {'id': '65c605d7f4fc8477f2ed6603',
#   'title': 'Madhav Marbles Consolidated December 2023 Net Sales at Rs 6.50 crore, down 29.3% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65ced045abb31841109cec68',
#   'title': 'Lancaster Colony Continues Higher Cash Dividend',
#   'category': 'market_news'},
#  {'id': '65c08790c119ff6e57a3f05e',
#   'title': 'Repro India Standalone December 2023 Net Sales at Rs 81.12 crore, up 5.49% Y-o-Y',
#   'category': 'market_news'},
#  {'id': '65c2f2eac119ff6e57a43dfe',
#   'title': 'Toggle3D.ai Announces its Breakthrough AI Increases 3D Model Production For Ecommerce Enterprise Customers Productivity by 100%',
#   'category': 'company_business_news'},
#  {'id': '65c44487da99411d474771ff',
#   'title': "UnitedHealth's chief operating officer Dirk McMahon to retire",
#   'category': 'company_business_news'},
#  {'id': '65c1d33dc119ff6e57a3fa26',
#   'title': 'CORRECTION: Bemax Announces the Launch of an Innovative Design for a Private Label Brand',
#   'category': 'company_business_news'},
#  {'id': '65c6e728f4fc8477f2ed6cf7',
#   'title': 'RPT-UPDATE 1-Bitcoin surges in biggest weekly rally in four months',
#   'category': 'market_news'},
#  {'id': '65c4441bda99411d47476c88',
#   'title': 'Trump fraud trial’s Judge Engoron eyeing whether CFO Allen Weisselberg lied on stand',
#   'category': 'non_financial'},
#  {'id': '65be1cd0f3aa2a77a58c061c',
#   'title': 'Capital Goods shares fall',
#   'category': 'market_news'},
#  {'id': '65ced04aabb31841109ceca5',
#   'title': 'Waymo Issues Recall After 2 Robotaxis Hit the Same Truck',
#   'category': 'company_business_news'},
#  {'id': '65cecfdeabb31841109ce607',
#   'title': "Occidental says CrownRock deal delayed by FTC requests of 'everything'",
#   'category': 'company_business_news'},
#  {'id': '65befdcaf3aa2a77a58c06c2',
#   'title': 'Interim Budget: Rs 2,502 cr allocated to law ministry, Rs 385 cr to EC',
#   'category': 'economic_policies_trends'},
#  {'id': '65ced06dabb31841109cee74',
#   'title': 'TSB raising the bar on safety: Reducing the risks that persist in commercial helicopter operations',
#   'category': 'company_business_news'},
#  {'id': '65c83852f4fc8477f2ed73f9',
#   'title': 'Ramco Industries consolidated net profit rises 3040.48% in the December 2023 quarter',
#   'category': 'market_news'},
#  {'id': '65c32aa0c119ff6e57a441bd',
#   'title': "Jack Henry's profit rises on higher demand for fintech products",
#   'category': 'market_news'},
#  {'id': '65cdb6bfabb31841109ce0ed',
#   'title': 'MORNING BID EUROPE-Asia techs bask in Nvidia afterglow',
#   'category': 'market_news'},
#  {'id': '65c2f2a7c119ff6e57a43a85',
#   'title': 'Laserfiche Channel Leadership Recognized by 2024 CRN® Channel Chiefs List',
#   'category': 'company_business_news'},
#  {'id': '65c605ecf4fc8477f2ed6722',
#   'title': 'Talbros Automotive hits the roof on good Q3 numbers',
#   'category': 'market_news'},
#  {'id': '65c1d515c119ff6e57a411ee',
#   'title': 'Wingstop (WING) Sees a More Significant Dip Than Broader Market: Some Facts to Know',
#   'category': 'market_news'},
#  {'id': '65c08781c119ff6e57a3f009',
#   'title': 'Apeejay Surrendra Park Hotels IPO: Retail portion fully booked within hours of opening; check latest GMP, other details | Mint',
#   'category': 'market_news'},
#  ...]

# %%
shortlisted_articles_dict = {x['article_id']: x['title'] for x in shortlisted_articles}

# %% [markdown]
# ### Hallucinations of the ids

# %%
wrong_article_ids = []
wrong_titles = []

# %%
for x in shortlisted_parsed_results:
    if x['id'] not in shortlisted_articles_dict:
        wrong_article_ids.append(x['id'])
        continue
    if x['title'] != shortlisted_articles_dict[x['id']]:
        wrong_titles.append(x['id'])

# %%
shortlisted_parsed_results[0]
# Out:
# {'id': '65c32ac0c119ff6e57a441f5',
#  'title': 'Nykredit today announces the Annual Reports for 2023 - Nykredit Realkredit A/S',
#  'category': 'company_business_news'}

# %%
len(wrong_article_ids)
# Out:
# 5

# %%
len(wrong_titles)
# Out:
# 2

# %%
invalid_article_ids = wrong_article_ids + wrong_titles

# %%
results_df = pd.DataFrame(shortlisted_parsed_results)

# %%
results_df = results_df[~results_df.id.isin(invalid_article_ids)]

# %%
results_df['test_flag'] = [1 if np.random.rand() <= 0.2 else 0 for _ in range(len(results_df)) ]

# %%
results_df.to_csv('titles_classes_gpt4_results.csv',index = False)

# %%
results_df.groupby(['test_flag', 'category'])['category'].count()
# Out:
# test_flag  category
# 0          company_business_news       1407
#            economic_policies_trends     530
#            market_news                 1692
#            non_financial                188
#            personal_finance             146
# 1          company_business_news        340
#            economic_policies_trends     115
#            market_news                  450
#            non_financial                 61
#            personal_finance              44
# Name: category, dtype: int64

# %% [markdown]
# #### Total cost

# %%
total_prompts = 0
total_completions = 0
for ind, results in title_class_results.items():
    total_prompts += results['prompt_tokens'] 
    total_completions += results['com_tokens']

# %%
total_cost = (0.06 * total_completions/1000) + (0.03 * total_prompts/1000)

# %%
total_cost
# Out:
# 23.13195
