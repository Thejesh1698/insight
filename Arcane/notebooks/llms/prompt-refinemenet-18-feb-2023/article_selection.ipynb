# %%
parent_folder = '/Users/ravi.tej/Desktop/ML/Recommendations/arcane/'
from hydra import compose, initialize
import os

import xml.etree.ElementTree as ET

tree = ET.parse('../../../conf/application.run.xml')
root = tree.getroot()

envs_element = root.find('./configuration/envs')
for variable in envs_element.findall('env'):
    name = variable.get('name')
    value = variable.get('value')
    os.environ[name] = value

import sys
sys.path.append('/Users/ravi.tej/Desktop/ML/Recommendations/arcane/')
import pandas as pd

# %%
from src.llm_finetuning.FTArticleSampling import FTArticleSampling

# %%
ArticleSampling = FTArticleSampling(num_articles=1000)

# %%
ArticleSampling.sample_articles()

# %%
from datetime import datetime

# %%
ArticleSampling.final_shortlisted_articles.to_csv(f'attributes_1000_shortlisted_articles_{datetime.now().strftime("%b_%d")}.csv',index = False)

# %%
len(ArticleSampling.final_shortlisted_articles)
# Out:
# 1185

# %%
ArticleSampling.final_shortlisted_articles.groupby('source_name')['article_id'].count()
# Out:
# source_name
# bbc                   25
# bq-prime              24
# business-insider      42
# business-standard     25
# business-world        64
# cnbc                  35
# cnbc-tv-18           100
# economic-times       120
# economist             25
# finshots              25
# groww                 25
# inc42                 25
# investopedia          87
# live-mint            214
# money-control        193
# navi                  24
# reuters               25
# wint-wealth           25
# yahoo-finance         57
# zerodha-varsity       25
# Name: article_id, dtype: int64
# 2024-02-19 07:43:01,696| ERROR   | Could not establish connection from local ('127.0.0.1', 3832) to remote ('insight-beta-article-db.cluster-chmaiagjipqy.ap-south-1.docdb.amazonaws.com', 27017) side of the tunnel: open new channel ssh error: Timeout opening channel.
# 2024-02-19 07:43:14,777| ERROR   | Socket exception: Operation timed out (60)
# ...

# %%
pd.options.display.max_columns = 30

# %%
ArticleSampling.final_shortlisted_articles.sample(30)
# Out:
#                                                       url  \
# 139550  https://economictimes.indiatimes.com/news/inte...
# 110598  https://economictimes.indiatimes.com/news/new-...
# 36170   https://economictimes.indiatimes.com/news/indi...
# 22851   https://www.moneycontrol.com/news/business/sta...
# 165333  https://inc42.com/buzz/nazara-q3-profits-zoom-...
# 10089   https://www.moneycontrol.com/news/business/eco...
# 98550   https://economictimes.indiatimes.com/news/scie...
# 151560  https://economictimes.indiatimes.com/news/defe...
# 117870  https://www.livemint.com/market/mark-to-market...
# 155231  https://www.bworldonline.com/top-stories/2023/...
# 88223          https://www.bbc.com/news/business-64949786
# 170007  https://www.businessinsider.com/best-selling-a...
# 121446  https://www.moneycontrol.com/news/business/ear...
# 93493   https://economictimes.indiatimes.com/news/indi...
# 255382  https://finance.yahoo.com/news/global-drug-dis...
# ...

# %%
pd.options.display.max_rows = 200

# %%
ArticleSampling.final_shortlisted_articles.groupby('fullcat')['article_id'].count().nlargest(300)
# Out:
# fullcat
# yahoo-finance--                                 126
# business-insider--                               70
# money-control-business-                          63
# cnbc--                                           60
# money-control-business-earnings                  54
# investopedia--                                   51
# bbc--                                            50
# wint-wealth-blog-                                50
# reuters--                                        50
# navi-blog-                                       50
# inc42--                                          50
# groww-blog-                                      50
# finshots--                                       50
# zerodha-varsity-varsity-                         50
# business-standard--                              50
# economist--                                      49
# live-mint-market-stock-market-news               46
# live-mint-market-live-blog                       44
# ...

# %%
ArticleSampling.fullcat_prob
# Out:
# fullcat
# bbc--                        0.008169
# bq-prime--                   0.000007
# bq-prime-business-           0.002684
# bq-prime-economy-finance-    0.000093
# bq-prime-ipos-               0.000214
#                                ...
# navi-blog-                   0.005905
# reuters--                    0.019356
# wint-wealth-blog-            0.006005
# yahoo-finance--              0.223130
# zerodha-varsity-varsity-     0.003042
# Name: article_id, Length: 226, dtype: float64
