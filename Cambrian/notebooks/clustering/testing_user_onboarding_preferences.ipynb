# %%
# !pip install hydra-core==1.3.2
# Out:
# ...
#   Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# ...
#   Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# ...
#   Using cached antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=d0c75fb8484d6a7f752eecdad1b2d674c6504d812e272021553fbd5d92284642
#   Stored in directory: /Users/ravi.tej/Library/Caches/pip/wheels/1a/97/32/461f837398029ad76911109f07047fde1d7b661a147c7c56d1
# Successfully built antlr4-python3-runtime
# ...

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------
# aiobotocore                   2.5.0
# aiofiles                      22.1.0
# aiohttp                       3.8.3
# aioitertools                  0.7.1
# aiosignal                     1.2.0
# aiosqlite                     0.18.0
# alabaster                     0.7.12
# anaconda-catalogs             0.2.0
# anaconda-client               1.12.0
# anaconda-navigator            2.4.2
# anaconda-project              0.11.1
# antlr4-python3-runtime        4.9.3
# anyio                         3.5.0
# appdirs                       1.4.4
# applaunchservices             0.3.0
# appnope                       0.1.2
# appscript                     1.1.2
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.1
# asttokens                     2.0.5
# async-timeout                 4.0.2
# ...

# %%
import sys

sys.path.insert(0, '/Users/ravi.tej/Desktop/ML/Recommendations/feed_recommendatios/')

# %%
from feed_recommendations.Onboarding import UserOnboardingPreferencesService
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from feed_recommendations.Onboarding import UserOnboardingPreferencesService
#
# File ~/Desktop/ML/Recommendations/feed_recommendatios/feed_recommendations/Onboarding/UserOnboardingPreferencesService.py:2
#       1 from collections import defaultdict
# ----> 2 from omegaconf import DictConfig
#       3 from typing import List, Dict
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'omegaconf'
